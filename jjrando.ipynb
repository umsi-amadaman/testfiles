# %% [markdown]
# # Information Visualization I
# ## School of Information, University of Michigan
#
# ## Week 3:
# - Perception / Cognition
#
# ## Assignment Overview
# ### This assignment's objectives include:
#
# - Review, refect, and apply the concepts of the perception pipeline. Justify how different encodings impact the effectiveness of a visualization depending on the human perception process.
#
# !["Drawing"](/voc/data/preattentive_resized.png)
#
# <p style="text-align: center;"> Preattentive Processing </p>
#
# - Recreate visualizations and propose new and alternative visualizations using [Altair](https://altair-viz.github.io/)
#
# ### The total score of this assignment will be 100 points consisting of:
# - Case study reflection: America's Favorite 'Star Wars' Movies (And Least Favorite Characters) (25 points)
# - Altair programming exercise (75 points)
#
# ### Resources:
# - Article by [FiveThirtyEight](https://fivethirtyeight.com) available  [online](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) (Hickey, 2014)
# - Datasets from FiveThirtyEight, we have downloaded a subset of this data in the folder [./assets](assets)
#     - The original dataset can be found at [FiveThirtyEight Star Wars Survey](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
#
# ### Important notes:
# 1) There will be a couple of places where the numbers you get when you select rows may be a little different than 538, but the percents should still work (e.g., 828 instead of 834). You'll see this in our examples. If you can somehow get the data to match exactly, that's great too.
#
# 2) A lot of this assignment will be based on building "compound" charts. Using the wrong strategy will mean that you are spending a lot of time "cleaning up" charts. We strongly suggest reading through (and understanding) the Altair documentation [on this](https://altair-viz.github.io/user_guide/compound_charts.html).
#
# 3) Grading for this assignment is entirely done by a human grader. They will be running tests on the functions we ask you to create. This means there is no autograding (submitting through the autograder will result in an error). You are expected to test and validate your own code.
#
# 4) Keep your notebooks clean and readable. If your code is highly messy or inefficient you will get a deduction.
#
# 5) Follow the instructions for submission on Coursera. You will be providing us a generated link to a read-only version of your notebook and a PDF. When turning in your PDF, please use the File -> Print -> Save as PDF option ***from your browser***. Do ***not*** use the File->Download as->PDF option. Complete instructions for this are under Resources in the Coursera page for this class. If you're having trouble with printing, take a look at [this video](https://youtu.be/PiO-K7AoWjk).

# %% [markdown]
# ## Part 1. Perception and Cognition (25 points)
# Read the article ["America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters),"](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) and answer the following questions:

# %% [markdown]
# ### 1.1 List the different data types in the following visualizations and their encodings (10 points)
# Look at the following visualizations. For each, list the variable, their type, and the encoding used.
#
# !["How rate visualization"](/voc/data/how_rate_resized.png)
# !["Have seen visualization"](/voc/data/have_seen_resized.png)
#
# Use the following table for each variable (indicate which vis each came from):
# * variable name, variable type (e.g., ordinal, nominal, etc.), variable encoding (e.g., color, x-position, etc.)
#
# For example, if you [look at this visualization](https://altair-viz.github.io/gallery/scatter_tooltips.html) one row in our table below would be: Horsepower, quantitative, x-position.

# %% [markdown]
# _1.1 Answer_
#
# *Use as many rows as you need*
#
# How People Rate the 'Star Wars' Movies
#
# | Variable name| Variable Type (Ordinal/Nominal/Quantitative) | Variable encoding (color, x-position, etc.) |
# | --- | --- | --- |
# |  Star Wars Movie Title | Nominal | Y-position|
# | Rank Category | Ordinal | x-posiiton |
# |  Rank Category | Ordinal | color |
# |  Percent in category | Quantitative | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
#
# Which 'Star Wars' Movies Have You Seen?
#
# | Variable name| Variable Type (Ordinal/Nominal/Quantitative) | Variable encoding (color, x-position, etc.) |
# | --- | --- | --- |
# |  Movie Title | Nominal | y-position |
# |  percent seen | x-axis | quantitative |
# |  Doesn't appear to be conditioned on a variable but it is colored blue | N/A | color |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
#
#
#
# ### 1.2 A Pie Chart Version (15 points)
#
#
# !["Drawing"](/voc/data/have_seen_resized.png)
#
# Your colleague is arguing that the chart above could be made more *effective* by using one or more pie charts. In what situations are they right? In what situations would they be wrong? If it helps makes your case, feel free to create a picture (hand drawn is fine) and load it into the notebook.

# %% [markdown]
# I don't think in the above chart that a pie chart would be correct. The reason for this is because a lot of the values are close to each other, and as we learned this week the human visual system is not especially equipped to accurately visualize difference in areas. This is especially applied here where we have a couple movies that are so close to each other in percentage. IF I HAD to point out a way this would be accurate is if we had broken this visual down into different groupingst that had more easily noticable separations. For example if we grouped them by trilogies, or another grouping that made sense and created a more stark contrast then we could say that a pie chart may show a more clear picture.

# %% [markdown]
# ## Part 2. Altair programming exercise (75 points)
# We have provided you with some code and parts of the article [America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/). This article is based on the dataset:
#
# 1. [StarWars](data/StarWars.csv) Created by FiveThirtyEight based on a survey ran through SurveyMonkey Audience, surveying 1,186 respondents from June 3 to 6 2014. Available [online] (https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
# To earn points for this assignment, you must:
#
# - Recreate the visualizations in the article (replace the images in the article with a code cell that creates a visualization). We provide one example. Each visualization is worth 10 points (40 points/ 10 each x 4 total ).
#
#     - _Partial credit can be granted for each visualization (up to 5 points) if you provide the grammar of graphics description of the visualization without a functional Altair implementation_
#
#
# - Propose two variants (a "good one" and a "bad one") for a new visualization for the article. You'll be asked to justify why one is better than the other. We are specifically interested in your explanation of why the "good one" is more *effective* based on principles of perception/cognition. (35 points/ 20 points for the plots + 15 for justification)

# %%
import pandas as pd
import altair as alt
import numpy as np
import math
from mads.lib.path import assets

# %%
# enable correct rendering
alt.renderers.enable('mimetype')
# Out:
# RendererRegistry.enable('mimetype')

# %%
# uses intermediate json files to speed things up
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
def loadStarwarsData(filename='StarWars.csv'):
    
    # input: filename to original dataset (default StarWars.csv)
    # output: cleaned up dataframe with columns appropriately renamed
    
    filename = assets.find(filename)
    sw = pd.read_csv(filename, encoding='latin1')

    # Some format is needed for the survey dataframe, we provide the formatted dataset in a dataframe 
    sw = sw.rename(columns={'Have you seen any of the 6 films in the Star Wars franchise?':'seen_any_movie',
                            'Do you consider yourself to be a fan of the Star Wars film franchise?': 'fan',
                            'Which of the following Star Wars films have you seen? Please select all that apply.' : 'seen_EI',
                            'Unnamed: 4' : 'seen_EII',
                            'Unnamed: 5' : 'seen_EIII',
                            'Unnamed: 6' : 'seen_EIV',
                            'Unnamed: 7' : 'seen_EV',
                            'Unnamed: 8' : 'seen_EVI',
                            'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.' : 'rank_EI',
                            'Unnamed: 10' : 'rank_EII',
                            'Unnamed: 11' : 'rank_EIII',
                            'Unnamed: 12' : 'rank_EIV',
                            'Unnamed: 13' : 'rank_EV',
                            'Unnamed: 14' : 'rank_EVI',
                            'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.' : 'Han Solo',
                            'Unnamed: 16' : 'Luke Skywalker',
                            'Unnamed: 17' : 'Princess Leia Organa',
                            'Unnamed: 18' : 'Anakin Skywalker',
                            'Unnamed: 19' : 'Obi Wan Kenobi',
                            'Unnamed: 20' : 'Emperor Palpatine',
                            'Unnamed: 21' : 'Darth Vader',
                            'Unnamed: 22' : 'Lando Calrissian',
                            'Unnamed: 23' : 'Boba Fett',
                            'Unnamed: 24' : 'C-3P0',
                            'Unnamed: 25' : 'R2 D2',
                            'Unnamed: 26' : 'Jar Jar Binks',
                            'Unnamed: 27' : 'Padme Amidala',
                            'Unnamed: 28' : 'Yoda',
                           })
    sw = sw.drop([0])
    return(sw)

sw = loadStarwarsData()

# %%
# take a peak to look at the data
sw.sample(5)
# Out:
#       RespondentID seen_any_movie  fan  \
# 438   3.290573e+09            Yes   No
# 140   3.291388e+09            Yes   No
# 1014  3.288654e+09            Yes  NaN
# 48    3.292190e+09            Yes  Yes
# 1088  3.288546e+09            Yes   No
#
#                                        seen_EI  \
# 438                                        NaN
# 140   Star Wars: Episode I  The Phantom Menace
# 1014                                       NaN
# 48    Star Wars: Episode I  The Phantom Menace
# 1088                                       NaN
#
#                                          seen_EII  \
# 438                                           NaN
# 140                                           NaN
# 1014                                          NaN
# 48    Star Wars: Episode II  Attack of the Clones
# 1088                                          NaN
#
#                                         seen_EIII  \
# 438                                           NaN
# 140   Star Wars: Episode III  Revenge of the Sith
# 1014                                          NaN
# 48    Star Wars: Episode III  Revenge of the Sith
# 1088                                          NaN
#
#                                seen_EIV  \
# 438                                 NaN
# 140                                 NaN
# 1014                                NaN
# 48    Star Wars: Episode IV  A New Hope
# 1088                                NaN
#
#                                            seen_EV  \
# 438   Star Wars: Episode V The Empire Strikes Back
# 140   Star Wars: Episode V The Empire Strikes Back
# 1014                                           NaN
# 48    Star Wars: Episode V The Empire Strikes Back
# 1088  Star Wars: Episode V The Empire Strikes Back
#
#                                       seen_EVI rank_EI  ...  \
# 438   Star Wars: Episode VI Return of the Jedi       3  ...
# 140   Star Wars: Episode VI Return of the Jedi       3  ...
# 1014                                       NaN     NaN  ...
# 48    Star Wars: Episode VI Return of the Jedi       5  ...
# 1088  Star Wars: Episode VI Return of the Jedi       3  ...
#
#                                              Yoda  \
# 438   Neither favorably nor unfavorably (neutral)
# 140                                Very favorably
# 1014                                          NaN
# 48                                 Very favorably
# 1088                               Very favorably
#
#            Which character shot first?  \
# 438   I don't understand this question
# 140   I don't understand this question
# 1014                               NaN
# 48                                 Han
# 1088  I don't understand this question
#
#      Are you familiar with the Expanded Universe?  \
# 438                                            No
# 140                                            No
# 1014                                          NaN
# 48                                            Yes
# 1088                                           No
#
#      Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 438                                                 NaN
# 140                                                 NaN
# 1014                                                NaN
# 48                                                  Yes
# 1088                                                NaN
#
#      Do you consider yourself to be a fan of the Star Trek franchise?  Gender  \
# 438                                                  No                  Male
# 140                                                  No                Female
# 1014                                                NaN                   NaN
# 48                                                  Yes                  Male
# 1088                                                 No                Female
#
#         Age   Household Income                         Education  \
# 438   45-60  $25,000 - $49,999                High school degree
# 140    > 60  $50,000 - $99,999  Some college or Associate degree
# 1014    NaN                NaN                               NaN
# 48    30-44  $50,000 - $99,999  Some college or Associate degree
# 1088   > 60  $50,000 - $99,999                   Graduate degree
#
#      Location (Census Region)
# 438            South Atlantic
# 140           Middle Atlantic
# 1014                      NaN
# 48         West North Central
# 1088       East North Central
#
# [5 rows x 38 columns]

# %% [markdown]
# # America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)

# %% [markdown]
# _Original article available at [FiveThirtyEight](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/)_
#
# By [Walt Hickey](https://fivethirtyeight.com/contributors/walt-hickey/)
#
# Filed under [Movies](https://fivethirtyeight.com/tag/movies/)
#
# Get the data on [GitHub](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)

# %% [markdown]
# This week, I caught a sneak peek [of the X-Wing fighter](http://www.wired.com/2014/07/star-wars-episode-vii-x-wing/) from the new “Star Wars” films in production. The forthcoming movies — and the middling response to the most recent trilogy — provide a perfect excuse to examine some questions I’ve long wanted answers to: How many people are “Star Wars” fans? Does the rest of America realize that “The Empire Strikes Back” is clearly the best of the bunch? Which characters are most well-liked and most hated? And who shot first, Han Solo or Greedo?
#
# We ran a poll through [SurveyMonkey Audience](https://www.surveymonkey.com/mp/audience/), surveying 1,186 respondents from June 3 to 6 (the [data](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey) is available [on GitHub](https://github.com/fivethirtyeight/data)). Seventy-nine percent of those respondents said they had watched at least one of the “Star Wars” films. This question, incidentally, had a substantial difference by gender: 85 percent of men have seen at least one “Star Wars” film compared to 72 percent of women. Of people who have seen a film, men were also more likely to consider themselves a fan of the franchise: 72 percent of men compared to 60 percent of women.
#
# We then asked respondents which of the films they had seen. With 835 people responding, here’s the probability that someone has seen a given “Star Wars” film given that they have seen any Star Wars film:

# %% [markdown]
# !["Sol1"](/voc/data/have_seen_resized.png)

# %%
# We're going to fix the labels a bit so will create a mapping to the full names
# and have the full sort order
def genEpisodeNamesDF():
    # create the various mapping and order lists/dictionaries
    # return: list of episodes (in order), episode->name map, list of episode names (in order)
    episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
    names = {
        'EI' : 'The Phantom Menace', 'EII' : 'Attack of the Clones', 'EIII' : 'Revenge of the Sith', 
        'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'The Return of the Jedi'
    }

    # we're also going to use this order to sort, so names_l will now have our sort order
    return episodes, names, [names[ep] for ep in episodes]

episodes, namesDict, namesList = genEpisodeNamesDF()

# %%
# let's inspect what we've generated. These will be useful to you below
print("abbreviated list (sorted):\n  ",episodes)
print("\nmapping between abberviated names and full titles:\n  ",namesDict)
print("\nfull titles, sorted:\n  ",namesList)
# Out:
# abbreviated list (sorted):
#    ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
#
# mapping between abberviated names and full titles:
#    {'EI': 'The Phantom Menace', 'EII': 'Attack of the Clones', 'EIII': 'Revenge of the Sith', 'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI': 'The Return of the Jedi'}
#
# full titles, sorted:
#    ['The Phantom Menace', 'Attack of the Clones', 'Revenge of the Sith', 'A New Hope', 'The Empire Strikes Back', 'The Return of the Jedi']

# %%
# let's do some data pre-processing... recall that sw (star wars) has everything

def getSeenAtLeastOneDF(indf, eps):
    # input: indf the data file as formatted above
    # input: eps a list of episodes (movies)

    # returns a substet of the dataset
    
    # We want to only use those people who have seen at least one movie, let's get the people, toss NAs
    # and get the total count

    # find people who have at least on of the columns (seen_*) not NaN
    salo = indf.dropna(subset=['seen_' + ep for ep in eps],how='all')
    
    return(salo)

# %%
seenAtLeastOneDF = getSeenAtLeastOneDF(sw, episodes)
print("total who have seen at least one: ", len(seenAtLeastOneDF),"\nSample:")
display(seenAtLeastOneDF.sample(5))
# Out:
# total who have seen at least one:  835
# Sample:
#       RespondentID seen_any_movie  fan  \
# 286   3.290845e+09            Yes  Yes
# 888   3.289459e+09            Yes  Yes
# 63    3.292120e+09            Yes  Yes
# 736   3.289835e+09            Yes  Yes
# 1153  3.288429e+09            Yes  Yes
#
#                                        seen_EI  \
# 286   Star Wars: Episode I  The Phantom Menace
# 888   Star Wars: Episode I  The Phantom Menace
# 63    Star Wars: Episode I  The Phantom Menace
# 736   Star Wars: Episode I  The Phantom Menace
# 1153  Star Wars: Episode I  The Phantom Menace
#
#                                          seen_EII  \
# 286   Star Wars: Episode II  Attack of the Clones
# 888   Star Wars: Episode II  Attack of the Clones
# 63    Star Wars: Episode II  Attack of the Clones
# 736   Star Wars: Episode II  Attack of the Clones
# 1153  Star Wars: Episode II  Attack of the Clones
#
#                                         seen_EIII  \
# 286   Star Wars: Episode III  Revenge of the Sith
# 888   Star Wars: Episode III  Revenge of the Sith
# 63    Star Wars: Episode III  Revenge of the Sith
# 736   Star Wars: Episode III  Revenge of the Sith
# 1153  Star Wars: Episode III  Revenge of the Sith
#
#                                seen_EIV  \
# 286   Star Wars: Episode IV  A New Hope
# 888   Star Wars: Episode IV  A New Hope
# 63    Star Wars: Episode IV  A New Hope
# 736   Star Wars: Episode IV  A New Hope
# 1153  Star Wars: Episode IV  A New Hope
#
#                                            seen_EV  \
# 286   Star Wars: Episode V The Empire Strikes Back
# 888   Star Wars: Episode V The Empire Strikes Back
# 63    Star Wars: Episode V The Empire Strikes Back
# 736   Star Wars: Episode V The Empire Strikes Back
# 1153  Star Wars: Episode V The Empire Strikes Back
#
#                                       seen_EVI rank_EI  ...            Yoda  \
# 286   Star Wars: Episode VI Return of the Jedi       4  ...  Very favorably
# 888   Star Wars: Episode VI Return of the Jedi       5  ...  Very favorably
# 63    Star Wars: Episode VI Return of the Jedi       4  ...  Very favorably
# 736   Star Wars: Episode VI Return of the Jedi       3  ...  Very favorably
# 1153  Star Wars: Episode VI Return of the Jedi       6  ...  Very favorably
#
#      Which character shot first? Are you familiar with the Expanded Universe?  \
# 286                          Han                                           No
# 888                       Greedo                                          Yes
# 63                           Han                                          Yes
# 736                          Han                                           No
# 1153                         Han                                          Yes
#
#      Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 286                                                 NaN
# 888                                                  No
# 63                                                  Yes
# 736                                                 NaN
# 1153                                                Yes
#
#      Do you consider yourself to be a fan of the Star Trek franchise?  Gender  \
# 286                                                 Yes                Female
# 888                                                 Yes                Female
# 63                                                   No                  Male
# 736                                                 Yes                  Male
# 1153                                                Yes                Female
#
#         Age     Household Income                         Education  \
# 286    > 60    $25,000 - $49,999  Some college or Associate degree
# 888   18-29    $50,000 - $99,999                   Bachelor degree
# 63    18-29  $100,000 - $149,999  Some college or Associate degree
# 736    > 60    $50,000 - $99,999  Some college or Associate degree
# 1153  18-29         $0 - $24,999  Some college or Associate degree
#
#      Location (Census Region)
# 286        West North Central
# 888            South Atlantic
# 63                New England
# 736        West North Central
# 1153       East North Central
#
# [5 rows x 38 columns]

# %%
# for each movie, we're going to calculate the percents and generate a new data frame

def genSeenPercentDf(inpf, names=namesDict, names_l=namesList):
    # input: inpf - an input frame of the form output by getSeenAtLeastOneDF()
    # input: names - a dictionary of abbreviations to names
    # input: names_l - a list of all the movies in series order
    
    total = len(inpf)
    percs = []

    # loop over each column and calculate the number of people who have seen the movie
    # specifically, filter out the people who are *NaN* for a specific episode (e.g., ep_EII), count them
    # and divide by the percent
    for seen_ep in ['seen_' + ep for ep in episodes]:
        perc = len(inpf[~ pd.isna(inpf[seen_ep])]) / total
        percs.append(perc)

    # at this point percs is holding our percentages

    # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
    tuples = list(zip([names[ep] for ep in episodes],percs))
    seen_per_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])
    return(seen_per_df)

# %%
seenPerMovieDF = genSeenPercentDf(seenAtLeastOneDF)

# %%
# let's see what's inside
seenPerMovieDF
# Out:
#                       Name  Percentage
# 0       The Phantom Menace    0.805988
# 1     Attack of the Clones    0.683832
# 2      Revenge of the Sith    0.658683
# 3               A New Hope    0.726946
# 4  The Empire Strikes Back    0.907784
# 5   The Return of the Jedi    0.883832

# %%
def genPercentVis(indf, names_l=namesList):
    # input: indf, the dataframe as seen_per_df
    # input: names_l - a list of all the movies in series order (default namesList)
    # output: simple altair bar chart
    
    # ok, time to make the chart... let's make a bar chart (use mark_bar)
    bars = alt.Chart(indf).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Percentage',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(tickCount=5, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=names_l
        )
    )

    # at this point we don't really have a great plot (it's missing the annotations, titles, etc.)
    return(bars)

seenPerMovieVis = genPercentVis(seenPerMovieDF)

# %%
# display it
seenPerMovieVis
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
def augmentPercentVis(base):
    # input: base (the base vis, i.e., bars as above)
    # we're going to overlay the text with the percentages, so let's make another visualization
    # that's just text labels


    text = base.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
    ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Percentage:Q',format='.0%')
    )

    # finally, we're going to combine the bars and the text and do some styling
    seen_movies = (text + base).configure_mark(
        # we don't love the blue
        color='#008fd5'
    ).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=180
    ).properties(
        # add a title
        title="Which 'Star Wars' Movies Have you Seen?"
    )

    return(seen_movies)

# note that we are NOT formatting this in the Five Thirty Eight Style yet... we'll leave that to you to figure out

# %%
# let's see it
augmentPercentVis(seenPerMovieVis)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# So we can see that “Star Wars: Episode V — The Empire Strikes Back” is the film seen by the most number of people, followed by “Star Wars: Episode VI — Return of the Jedi.” Appallingly, more people reported seeing “Star Wars: Episode I — The Phantom Menace” than the original “Star Wars” (renamed “Star Wars: Episode IV — A New Hope”).
#
# So, which movie is the best? We asked the subset of 471 respondents who indicated they have seen every “Star Wars” film to rank them from best to worst. From that question, we calculated the share of respondents who rated each film as their favorite.

# %% [markdown]
# !["Sol1"](/voc/data/best_movie_article_resized.png)
#
#
# ** Homework note: Click [here](/voc/data/best_movie.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.1 What's the best 'Star Wars' movie? Recreate the above image using altair (10 Points)
#
# Recreate the image above using Altair. Match the "538" style as best you can (hint: look at the altair lab at the start of the semester). We expect you to *at least* match the [our version](best_movie.png) of the chart that was created in Altair.

# %%
# Recreate this image using Altair
# match the "538 style" as best you can (hint: look at the altair lab at the start of the semester)

def genBestVis(inpf,eps, names=namesDict, names_l=namesList):

    seen_all = inpf.dropna(subset = ['seen_EI','seen_EII','seen_EIII','seen_EIV','seen_EV','seen_EVI'])
    perc_best = []
    # finally, we're going to combine the bars and the text and do some styling
    for rank_ep in ['rank_' + ep for ep in names]:
        filter_nan = seen_all.fillna(0) 
        perc = ((np.round(len(filter_nan[filter_nan[rank_ep].astype(int) == 1]) / len(seen_all),2)))
        perc_best.append(perc)

    best_tuple = list(zip([names[ep] for ep in episodes],perc_best))
    best_df = pd.DataFrame(best_tuple, columns = ['Name','Perc'])
    

    bars = alt.Chart(best_df, title=alt.Title(
       "What's the Best 'Star Wars' Movie",
       subtitle="Of 471 respondents who have seen all six films", anchor='start')).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Perc',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(tickCount=5, domain = False, ticks=False, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=names_l))

    text = bars.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
        ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Perc:Q',format='.0%')
    )
    

    
    seen_movies = (text + bars).configure_mark(
        # we don't love the blue
        color='#008fd5'
    ).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=180
    ).configure(background='#f0f0f0').configure_view(stroke=None).configure_axisY(labelPadding = 5)
    return seen_movies

# %%
# test your code
genBestVis(sw,episodes)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# ## Make sure to *style* your visualization to match the original the best you can

# %% [markdown]
# We can also drill down and find out, generally, how people rate the films. Overall, fans broke into two camps: those who preferred the original three movies and those who preferred the three prequels. People who said “The Empire Strikes Back” was their favorite were also likely to rate “A New Hope” and “Return of the Jedi” higher as well. Those who rated “The Phantom Menace” as the best film were more likely to rate prequels higher.
#
# This chart shows how often each film was rated in the top third (best or second-best), the middle third (third or fourth) or the bottom third (second-worst or worst). It’s a more nuanced take on the series:

# %% [markdown]
# !["Sol1"](/voc/data/how_rate_resized.png)
#
# ** Homework note: Click [here](/voc/data/people_rate.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.2 How people rate the 'Star Wars' movie? Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)

def genRateVis(inpf,eps, names=namesDict, names_l=namesList):

    seen_all = inpf.dropna(subset = ['seen_EI','seen_EII','seen_EIII','seen_EIV','seen_EV','seen_EVI'])
    top_third_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for rank_ep in ['rank_' + ep for ep in eps]:
        top_third_percs = (np.round(len(seen_all[seen_all[rank_ep].isin(['1','2'])]) / len(seen_all),2))
        top_third_perc.append(top_third_percs)

    top_third_tuple = list(zip([names[ep] for ep in episodes],top_third_perc))
    top_third_df = pd.DataFrame(top_third_tuple, columns = ['Name','Perc'])
    top_third_df['Third'] = 'Top third'

    
    mid_third_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for rank_ep in ['rank_' + ep for ep in eps]:
        mid_third_percs = (np.round(len(seen_all[seen_all[rank_ep].isin(['3','4'])]) / len(seen_all),2))
        mid_third_perc.append(mid_third_percs)

    mid_third_tuple = list(zip([names[ep] for ep in episodes],mid_third_perc))
    mid_third_df = pd.DataFrame(mid_third_tuple, columns = ['Name','Perc'])
    mid_third_df['Third'] = 'Middle third'

    bot_third_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for rank_ep in ['rank_' + ep for ep in eps]:
        bot_third_percs = (np.round(len(seen_all[seen_all[rank_ep].isin(['5','6'])]) / len(seen_all),2))
        bot_third_perc.append(bot_third_percs)

    bot_third_tuple = list(zip([names[ep] for ep in episodes],bot_third_perc))
    bot_third_df = pd.DataFrame(bot_third_tuple, columns = ['Name','Perc'])
    bot_third_df['Third'] = 'Bottom third'   

    colors_scale = alt.Scale(domain=['Top third', 'Middle third', 'Bottom third'], range = ['#77ab43', '#008fd5', '#FF2701'])
    thirds_df = pd.concat([top_third_df,mid_third_df, bot_third_df], axis = 0)
    bars_thirds = alt.Chart(thirds_df, title=alt.Title(
       "What's the Best 'Star Wars' Movie",
       subtitle="Of 471 respondents who have seen all six films", anchor='start')).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Perc',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(ticks=False, domain=False, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=names_l),
        color=alt.Color('Third:N', scale = colors_scale, legend = None))
        
    

    text_thirds = bars_thirds.mark_text(
        align='left',
        baseline='middle',
        color='black',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
        ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Perc:Q',format='.0%')
    )

    
    #Created faceted/layered charts. Adjusted width so columns are similar in size, and title is the correct lines 
    thirds_movies = (text_thirds + bars_thirds).properties(
        # set the dimensions of the visualization            
        width=50,
        height=180
    ).facet(alt.Facet(shorthand='Third:N', sort = ['descending'], title=None)).properties(title=alt.TitleParams(
            text="How People Rate the 'Star Wars' Movies",
            subtitle=["How often each film was rated in the top, middle, and bottom third", "(by 471 respondents who have seen all six films)", ""],
            anchor = 'start')).configure_facet(spacing=0).configure(background='#f0f0f0').configure_view(strokeWidth=0).resolve_scale(x='shared').configure_axisY(labelPadding = 5)

    return thirds_movies

# %%
# let's check our solution
genRateVis(sw,episodes)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# Finally, we took a boilerplate format used by political favorability polls — “Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her” — and asked respondents to rate characters in the series.

# %% [markdown]
# !["Sol1"](/voc/data/char_ranking_resized.png)
#
#
# ** Homework note. Here's an example solution generated in Altair:
# !["Sol1"](/voc/data/people_rate_s.png)
#
# Be careful here in what you're dividing by to get the totals for each character.

# %% [markdown]
# ### 2.3 Star Wars' Characters Favorability Ratings. Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)

def genFavorabilityVis(inpf):
    # input: inpf, the star wars dataset (as defined at top of file)
    # output: the Altair visualization as described above
    order_char = ['Luke Skywalker','Han Solo', 'Princess Leia Organa','Obi Wan Kenobi','Yoda','R2 D2','C-3P0', 'Anakin Skywalker','Darth Vader', 'Lando Calrissian','Padme Amidala', 'Boba Fett', 'Emperor Palpatine', 'Jar Jar Binks']
    favorable_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        favorable_percs = (np.round(len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])]) / len(filt_df),2))
        favorable_perc.append(favorable_percs)
    fav_tuple = list(zip([chars for chars in order_char],favorable_perc))
    fav_tuple_df = pd.DataFrame(fav_tuple, columns = ['Name','Perc'])
    fav_tuple_df['Rating'] = 'Favorable'

    
    neutral_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        neutral_percs = (np.round(len(filt_df[filt_df[char].isin(['Neither favorably nor unfavorably (neutral)'])]) / len(filt_df),2))
        neutral_perc.append(neutral_percs)

    neutral_tuple = list(zip([chars for chars in order_char],neutral_perc))
    neutral_tuple_df = pd.DataFrame(neutral_tuple, columns = ['Name','Perc'])
    neutral_tuple_df['Rating'] = 'Neutral'

    unfav_perc = []
    for char in order_char:
        filt_df = inpf[inpf[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        unfav_percs = (np.round(len(filt_df[filt_df[char].isin(['Somewhat unfavorably', 'Very unfavorably',])]) / len(filt_df),2))
        unfav_perc.append(unfav_percs)

    unfav_tuple = list(zip([chars for chars in order_char],unfav_perc))
    unfav_tuple_df = pd.DataFrame(unfav_tuple, columns = ['Name','Perc'])
    unfav_tuple_df['Rating'] = 'Unfavorable'

    unfam_perc = []
    for char in order_char:
        filt_df = inpf[inpf[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        unfam_percs = (np.round(len(filt_df[filt_df[char].isin(['Unfamiliar (N/A)'])]) / len(filt_df),2))
        unfam_perc.append(unfam_percs)

    unfam_tuple = list(zip([chars for chars in order_char],unfam_perc))
    unfam_tuple_df = pd.DataFrame(unfam_tuple, columns = ['Name','Perc'])
    unfam_tuple_df['Rating'] = 'Unfamiliar'
    
    
    colors_scale = alt.Scale(domain=['Favorable', 'Neutral', 'Unfavorable', 'Unfamiliar'], range = ['#77ab43', '#008fd5', '#FF2701','#999999'])
    rates_df = pd.concat([fav_tuple_df, neutral_tuple_df, unfav_tuple_df,unfam_tuple_df ], axis = 0)
    bars_rates = alt.Chart(rates_df, title=alt.Title(
       "What's the Best 'Star Wars' Movie",
       subtitle="Of 471 respondents who have seen all six films", anchor='start')).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Perc',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(ticks=False, domain=False, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=order_char),
        color=alt.Color('Rating:N', scale = colors_scale, legend = None))
        
    

    text_rates = bars_rates.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
        ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Perc:Q',format='.0%')
    )

    
    #Created faceted/layered charts. Adjusted width so columns are similar in size, and title is the correct lines 
    rate_chars = (text_rates + bars_rates).properties(
        # set the dimensions of the visualization            
        width=100,
        height=300
    ).facet(alt.Facet(shorthand='Rating:N', sort = ['descending'], title=None)).properties(title=alt.TitleParams(
            text="'Star Wars' Character Favorability Ratings",
            subtitle=["By 834 respondents", ""],
            anchor = 'start')).configure_facet(spacing=0).configure(background='#f0f0f0').configure_view(strokeWidth=0).resolve_scale(x='shared').configure_axisY(labelPadding = 5)

    return rate_chars

# %%
# let's test the solution
genFavorabilityVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# !["Sol1"](/voc/data/shot_first_article_resized.png)
#
#
# ** Homework note: Click [here](/voc/data/shot_first.png) to see a version of this plot generated in Altair. You may find that you don't get 834 rows (as 538 did) but the percents should still work.

# %% [markdown]
# ### 2.4 Who shot first? Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)

def genFirstShotVis(inpf):
    who_shot = ['Han','Greedo',"I don't understand this question"] 
    perc_shot = []
    # finally, we're going to combine the bars and the text and do some styling
    for who in who_shot:
        filter_nan = inpf.dropna(subset=['Which character shot first?'])
        perc = ((np.round(len(filter_nan[filter_nan['Which character shot first?'] == who]) / len(filter_nan),2)))
        perc_shot.append(perc)

    who_shot_tuple = list(zip([who for who in who_shot],perc_shot))
    who_shot_df = pd.DataFrame(who_shot_tuple, columns = ['Name','Perc'])
    

    bars = alt.Chart(who_shot_df, title=alt.Title(
       "Who Shot First?",
       subtitle="According to 834 respondents", anchor='start')).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Perc',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(ticks = False, domain=False, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=who_shot))

    text = bars.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
        ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Perc:Q',format='.0%')
    )
    

    
    who_shot_chart = (text + bars).configure_mark(
        # we don't love the blue
        color='#008fd5'
    ).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=110
    ).configure(background='#f0f0f0').configure_view(stroke=None).configure_axisY(labelPadding = 5)
    return who_shot_chart

# %%
# test our solution
genFirstShotVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# ### 2.5 Make your own (35 points total - 20 for implementation, 15 for justification)

# %% [markdown]
# Reading through the article, identify some aspect of the story that would benefit from an extra visualization (you can imagine extending the article if it helps). We would like for you to create two versions of this hypothetical visualization.  You should be able to convincingly argue that one visualization is better than the other.
#
# Note: The two visualizations should use different marks and at least some of the encodings should be different. If you're struggling with coming up with two really different representations, your visualization may simply be too simple. Try to add additional columns/comparisons.

# %%
def genGoodFavEduVis(inpf):
    # input: inpf, the star wars dataset (as defined at top of file)
    # output: the Altair visualization as described above
    order_char = ['Luke Skywalker','Han Solo', 'Princess Leia Organa','Obi Wan Kenobi','Yoda','R2 D2','C-3P0', 'Anakin Skywalker','Darth Vader', 'Lando Calrissian','Padme Amidala', 'Boba Fett', 'Emperor Palpatine', 'Jar Jar Binks']
    education = ['Graduate degree','Bachelor degree','Some college or Associate degree', 'High school degree','Less than high school degree']
    
    grad_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Graduate degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        grad_percs = (np.round(len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])]) / len(filt_df),2))
        grad_perc.append(grad_percs)
    grad_tuple = list(zip([chars for chars in order_char],grad_perc))
    grad_tuple_df = pd.DataFrame(grad_tuple, columns = ['Name','Perc'])
    grad_tuple_df['Education'] = 'Graduate degree'

    bach_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Bachelor degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        bach_percs = (np.round(len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])]) / len(filt_df),2))
        bach_perc.append(bach_percs)
    bach_tuple = list(zip([chars for chars in order_char],bach_perc))
    bach_tuple_df = pd.DataFrame(bach_tuple, columns = ['Name','Perc'])
    bach_tuple_df['Education'] = 'Bachelor degree'

    some_coll_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Some college or Associate degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        some_coll_percs = (np.round(len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])]) / len(filt_df),2))
        some_coll_perc.append(some_coll_percs)
    some_coll_perc_tuple = list(zip([chars for chars in order_char],some_coll_perc))
    some_coll_tuple_df = pd.DataFrame(some_coll_perc_tuple, columns = ['Name','Perc'])
    some_coll_tuple_df['Education'] = 'Some college/Associate degree'

    high_school_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['High school degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        high_school_percs = (np.round(len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])]) / len(filt_df),2))
        high_school_perc.append(high_school_percs)
    high_school_perc_tuple = list(zip([chars for chars in order_char],high_school_perc))
    high_school_tuple_df = pd.DataFrame(high_school_perc_tuple, columns = ['Name','Perc'])
    high_school_tuple_df['Education'] = 'High school'

    less_high_school_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Less than high school degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        less_high_school_percs = (np.round(len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])]) / len(filt_df),2))
        less_high_school_perc.append(less_high_school_percs)
    less_high_school_perc_tuple = list(zip([chars for chars in order_char],less_high_school_perc))
    less_high_school_tuple_df = pd.DataFrame(less_high_school_perc_tuple, columns = ['Name','Perc'])
    less_high_school_tuple_df['Education'] = 'Less than HS'
    
    
    colors_scale = alt.Scale(domain=['Graduate degree', 'Bachelor degree', 'Some college/Associate degree', 'High school','Less than HS'], range = ['#e75480','#77ab43', '#008fd5', '#FF2701','#999999', ])
    edu_fav_df = pd.concat([grad_tuple_df, bach_tuple_df, some_coll_tuple_df,high_school_tuple_df, less_high_school_tuple_df], axis = 0)
    bars_rates = alt.Chart(edu_fav_df, title=alt.Title(
       "What's the Best 'Star Wars' Movie",
       subtitle="Of 471 respondents who have seen all six films", anchor='start')).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Perc',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(ticks=False, domain=False, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=order_char),
        color=alt.Color('Education:N', scale = colors_scale, legend = None))
        
    

    text_rates = bars_rates.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
        ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Perc:Q',format='.0%')
    )

    
    #Created faceted/layered charts. Adjusted width so columns are similar in size, and title is the correct lines 
    rate_chars = (text_rates + bars_rates).properties(
        # set the dimensions of the visualization            
        width=100,
        height=300
    ).facet(alt.Facet(shorthand='Education:N', sort = ['descending'], title=None)).properties(title=alt.TitleParams(
            text="'Star Wars' Character Favorability by Education level",
            subtitle=[""],
            anchor = 'start')).configure_facet(spacing=0).configure(background='#f0f0f0').configure_view(strokeWidth=0).resolve_scale(x='shared').configure_axisY(labelPadding = 5)

    return rate_chars

# %%
genGoodFavEduVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
def genBadFavEduVis(inpf):
    # input: inpf, the star wars dataset (as defined at top of file)
    # output: the Altair visualization as described above
    order_char = ['Luke Skywalker','Han Solo', 'Princess Leia Organa','Obi Wan Kenobi','Yoda','R2 D2','C-3P0', 'Anakin Skywalker','Darth Vader', 'Lando Calrissian','Padme Amidala', 'Boba Fett', 'Emperor Palpatine', 'Jar Jar Binks']
    education = ['Graduate degree','Bachelor degree','Some college or Associate degree', 'High school degree','Less than high school degree']
    
    grad_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Graduate degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        grad_percs = len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])])
        grad_perc.append(grad_percs)
    grad_tuple = list(zip([chars for chars in order_char],grad_perc))
    grad_tuple_df = pd.DataFrame(grad_tuple, columns = ['Name','Count'])
    grad_tuple_df['Education'] = 'Graduate degree'

    bach_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Bachelor degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        bach_percs = len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])])
        bach_perc.append(bach_percs)
    bach_tuple = list(zip([chars for chars in order_char],bach_perc))
    bach_tuple_df = pd.DataFrame(bach_tuple, columns = ['Name','Count'])
    bach_tuple_df['Education'] = 'Bachelor degree'

    some_coll_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Some college or Associate degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        some_coll_percs = len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])])
        some_coll_perc.append(some_coll_percs)
    some_coll_perc_tuple = list(zip([chars for chars in order_char],some_coll_perc))
    some_coll_tuple_df = pd.DataFrame(some_coll_perc_tuple, columns = ['Name','Count'])
    some_coll_tuple_df['Education'] = 'Some college/Associate degree'

    high_school_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['High school degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        high_school_percs = len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])])
        high_school_perc.append(high_school_percs)
    high_school_perc_tuple = list(zip([chars for chars in order_char],high_school_perc))
    high_school_tuple_df = pd.DataFrame(high_school_perc_tuple, columns = ['Name','Count'])
    high_school_tuple_df['Education'] = 'High school'

    less_high_school_perc = []
    # finally, we're going to combine the bars and the text and do some styling
    for char in order_char:
        filt_df = inpf[inpf['Education'].isin(['Less than high school degree'])]
        filt_df = filt_df.dropna(subset=['Education'])
        filt_df = filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably', 'Neither favorably nor unfavorably (neutral)', 'Somewhat unfavorably', 'Very unfavorably', 'Unfamiliar (N/A)'])]
        less_high_school_percs = len(filt_df[filt_df[char].isin(['Very favorably', 'Somewhat favorably'])])
        less_high_school_perc.append(less_high_school_percs)
    less_high_school_perc_tuple = list(zip([chars for chars in order_char],less_high_school_perc))
    less_high_school_tuple_df = pd.DataFrame(less_high_school_perc_tuple, columns = ['Name','Count'])
    less_high_school_tuple_df['Education'] = 'Less than HS'
    
    
    colors_scale = alt.Scale(domain=['Graduate degree', 'Bachelor degree', 'Some college/Associate degree', 'High school','Less than HS'], range = ['#e75480','#77ab43', '#008fd5', '#FF2701','#999999', ])
    edu_fav_df = pd.concat([grad_tuple_df, bach_tuple_df, some_coll_tuple_df,high_school_tuple_df, less_high_school_tuple_df], axis = 0)

    base = alt.Chart(edu_fav_df).mark_arc(outerRadius = 150)

    pie_chart = base.encode(
        theta = alt.Theta("Count:Q", stack=True),
                          color=alt.Color("Education:N"))
    pie_chart = pie_chart.facet(alt.Facet(shorthand='Name:N', title=None))    

    return pie_chart

# %%
genBadFavEduVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# #### Justification
# *Provide your justification here* to argue why your "better" version is actually better. Make sure to defend this based on expressiveness and effectiveness as well as perceptual arguments.

# %% [markdown]
# First, I wanted to set up the reason why I chose to visualize what I had chosen. I remember hearing an anecdote as a teen that favorability, or lack thereof in the case of Jar Jar Binks, had correlation with either education or intelligence. The exact variable is lost on me now. So for this example, I chose to chart every character’s favorability by education level. To see how this contrasted with this rumor I had heard years ago. The first chart is the better chart. This is due to a few reasons: For one, the titles and charts are much better ordered. There is both a title for the overall chart as well as clear labelling for the education levels and the characters. In addition to this, the colors are contrasting and colors like red and pink although similar in palette are separated far enough that there should not be confusion or overlap. Also, there are numerals indicating what exactly each bar % is and the groups are ordered from highest level to lowest level of education. Making it easy to digest, but also compare across the groups. This provides both and expressive and effective visualization.
#
# In the worst visual, I chose the same measurements, however this time I used pie charts. This is clearly worse for quite a few reasons. First, it is extremely wide. This creates a visual that is not easily digested in one glance. It also uses a legend rather than labelling the actual pieces of the visual, requiring the user to scroll/look at the legend and then back at each chart to digest the color scheme meaning. There are also very small, very large, and very similar slices, this coupled with not having numerals for each slice of the pie mans the audience must use their, as we have learned, less than ideal perception of area to guess what percent of the pie belongs to each education level. A task which in some respects is very difficult and in others nearly impossible. It is also ordered alphabetically, and not by education level or anything meaningful for our message. The last issue with this visual is that it is now telling us something completely different than the previous chart. This is telling us what proportion of people from each education level makes up the overall total of people who find these characters favorable. This part I left for last, because it shows how, without proper labelling and titling, two charts that appear to represent the same thing, might not even do that. This example is lacking in both expressiveness and effectiveness.
