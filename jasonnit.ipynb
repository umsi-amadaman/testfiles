# %% [markdown]
# # Information Visualization I
# ## School of Information, University of Michigan
#
# ## Week 3:
# - Perception / Cognition
#
# ## Assignment Overview
# ### This assignment's objectives include:
#
# - Review, refect, and apply the concepts of the perception pipeline. Justify how different encodings impact the effectiveness of a visualization depending on the human perception process.
#
# !["Drawing"](/voc/data/preattentive_resized.png)
#
# <p style="text-align: center;"> Preattentive Processing </p>
#
# - Recreate visualizations and propose new and alternative visualizations using [Altair](https://altair-viz.github.io/)
#
# ### The total score of this assignment will be 100 points consisting of:
# - Case study reflection: America's Favorite 'Star Wars' Movies (And Least Favorite Characters) (25 points)
# - Altair programming exercise (75 points)
#
# ### Resources:
# - Article by [FiveThirtyEight](https://fivethirtyeight.com) available  [online](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) (Hickey, 2014)
# - Datasets from FiveThirtyEight, we have downloaded a subset of this data in the folder [./assets](assets)
#     - The original dataset can be found at [FiveThirtyEight Star Wars Survey](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
#
# ### Important notes:
# 1) There will be a couple of places where the numbers you get when you select rows may be a little different than 538, but the percents should still work (e.g., 828 instead of 834). You'll see this in our examples. If you can somehow get the data to match exactly, that's great too.
#
# 2) A lot of this assignment will be based on building "compound" charts. Using the wrong strategy will mean that you are spending a lot of time "cleaning up" charts. We strongly suggest reading through (and understanding) the Altair documentation [on this](https://altair-viz.github.io/user_guide/compound_charts.html).
#
# 3) Grading for this assignment is entirely done by a human grader. They will be running tests on the functions we ask you to create. This means there is no autograding (submitting through the autograder will result in an error). You are expected to test and validate your own code.
#
# 4) Keep your notebooks clean and readable. If your code is highly messy or inefficient you will get a deduction.
#
# 5) Follow the instructions for submission on Coursera. You will be providing us a generated link to a read-only version of your notebook and a PDF. When turning in your PDF, please use the File -> Print -> Save as PDF option ***from your browser***. Do ***not*** use the File->Download as->PDF option. Complete instructions for this are under Resources in the Coursera page for this class. If you're having trouble with printing, take a look at [this video](https://youtu.be/PiO-K7AoWjk).

# %% [markdown]
# ## Part 1. Perception and Cognition (25 points)
# Read the article ["America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters),"](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) and answer the following questions:

# %% [markdown]
# ### 1.1 List the different data types in the following visualizations and their encodings (10 points)
# Look at the following visualizations. For each, list the variable, their type, and the encoding used.
#
# !["How rate visualization"](/voc/data/how_rate_resized.png)
# !["Have seen visualization"](/voc/data/have_seen_resized.png)
#
# Use the following table for each variable (indicate which vis each came from):
# * variable name, variable type (e.g., ordinal, nominal, etc.), variable encoding (e.g., color, x-position, etc.)
#
# For example, if you [look at this visualization](https://altair-viz.github.io/gallery/scatter_tooltips.html) one row in our table below would be: Horsepower, quantitative, x-position.

# %% [markdown]
# _1.1 Answer_
#
# *Use as many rows as you need*
#
# How People Rate the 'Star Wars' Movies
#
# | Variable name| Variable Type (Ordinal/Nominal/Quantitative) | Variable encoding (color, x-position, etc.) |
# | --- | --- | --- |
# |  *Movie Name* | *Nominal* | *Y Position* |
# |  *Rank Position (top, middle, bottom third)* | *Ordinal* | *X Position, Color* |
# |  *Percent of respondants* | *quantitative* | *bar width, bar labels* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
#
# Which 'Star Wars' Movies Have You Seen?
#
# | Variable name| Variable Type (Ordinal/Nominal/Quantitative) | Variable encoding (color, x-position, etc.) |
# | --- | --- | --- |
# |  *Movie Name* | *Nominal* | *Y Position* |
# |  *Percent of respondants* | *quantitative* | *bar width, bar labels* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |

# %% [markdown]
# ### 1.2 A Pie Chart Version (15 points)
#
#
# !["Drawing"](/voc/data/have_seen_resized.png)
#
# Your colleague is arguing that the chart above could be made more *effective* by using one or more pie charts. In what situations are they right? In what situations would they be wrong? If it helps makes your case, feel free to create a picture (hand drawn is fine) and load it into the notebook.

# %% [markdown]
# **My colleague is correct that the above chart would be more effective by using pie charts instead of bar charts for the percentage of each movie that viewers have seen.  The issue with the bar charts is that it is hard to tell where 100% is, so pie charts can be more effective at measuring this aspect.  For example, if you look at the chart below on the left, if we had 6 pie charts instead of 6 bar charts, you will get a better sense of what % of respondants have seen each movie.  However, a con of the 6 pie charts is that it makes it harder to compare between movies what % of people have watched them.**
#
# **A bad way to create a pie chart is to combine all the values into 1 chart, as users can watch multiple movies so the percents add up to more than 100%.  The right chart with all 6 movies in one pie chart loses the ability to compare movies to one another while not gaining the benefits of the left pie charts where it is easier to visualize the % of viewers that have seen each movie.**

# %% [markdown]
# !["Drawing"](starwars.png)

# %% [markdown]
# ## Part 2. Altair programming exercise (75 points)
# We have provided you with some code and parts of the article [America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/). This article is based on the dataset:
#
# 1. [StarWars](data/StarWars.csv) Created by FiveThirtyEight based on a survey ran through SurveyMonkey Audience, surveying 1,186 respondents from June 3 to 6 2014. Available [online] (https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
# To earn points for this assignment, you must:
#
# - Recreate the visualizations in the article (replace the images in the article with a code cell that creates a visualization). We provide one example. Each visualization is worth 10 points (40 points/ 10 each x 4 total ).
#
#     - _Partial credit can be granted for each visualization (up to 5 points) if you provide the grammar of graphics description of the visualization without a functional Altair implementation_
#
#
# - Propose two variants (a "good one" and a "bad one") for a new visualization for the article. You'll be asked to justify why one is better than the other. We are specifically interested in your explanation of why the "good one" is more *effective* based on principles of perception/cognition. (35 points/ 20 points for the plots + 15 for justification)

# %%
import pandas as pd
import altair as alt
import numpy as np
import math
from mads.lib.path import assets

# %%
# enable correct rendering
alt.renderers.enable('mimetype')
# Out:
# RendererRegistry.enable('mimetype')

# %%
# uses intermediate json files to speed things up
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
def loadStarwarsData(filename='StarWars.csv'):
    
    # input: filename to original dataset (default StarWars.csv)
    # output: cleaned up dataframe with columns appropriately renamed
    
    filename = assets.find(filename)
    sw = pd.read_csv(filename, encoding='latin1')

    # Some format is needed for the survey dataframe, we provide the formatted dataset in a dataframe 
    sw = sw.rename(columns={'Have you seen any of the 6 films in the Star Wars franchise?':'seen_any_movie',
                            'Do you consider yourself to be a fan of the Star Wars film franchise?': 'fan',
                            'Which of the following Star Wars films have you seen? Please select all that apply.' : 'seen_EI',
                            'Unnamed: 4' : 'seen_EII',
                            'Unnamed: 5' : 'seen_EIII',
                            'Unnamed: 6' : 'seen_EIV',
                            'Unnamed: 7' : 'seen_EV',
                            'Unnamed: 8' : 'seen_EVI',
                            'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.' : 'rank_EI',
                            'Unnamed: 10' : 'rank_EII',
                            'Unnamed: 11' : 'rank_EIII',
                            'Unnamed: 12' : 'rank_EIV',
                            'Unnamed: 13' : 'rank_EV',
                            'Unnamed: 14' : 'rank_EVI',
                            'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.' : 'Han Solo',
                            'Unnamed: 16' : 'Luke Skywalker',
                            'Unnamed: 17' : 'Princess Leia Organa',
                            'Unnamed: 18' : 'Anakin Skywalker',
                            'Unnamed: 19' : 'Obi Wan Kenobi',
                            'Unnamed: 20' : 'Emperor Palpatine',
                            'Unnamed: 21' : 'Darth Vader',
                            'Unnamed: 22' : 'Lando Calrissian',
                            'Unnamed: 23' : 'Boba Fett',
                            'Unnamed: 24' : 'C-3P0',
                            'Unnamed: 25' : 'R2 D2',
                            'Unnamed: 26' : 'Jar Jar Binks',
                            'Unnamed: 27' : 'Padme Amidala',
                            'Unnamed: 28' : 'Yoda',
                           })
    sw = sw.drop([0])
    return(sw)

sw = loadStarwarsData()

# %%
# take a peak to look at the data
pd.set_option('display.max_columns', 50)
sw.sample(3)
# Out:
#       RespondentID seen_any_movie  fan  \
# 65    3.292050e+09            Yes   No
# 1004  3.288669e+09            Yes  Yes
# 650   3.290011e+09            Yes  Yes
#
#                                        seen_EI  \
# 65    Star Wars: Episode I  The Phantom Menace
# 1004  Star Wars: Episode I  The Phantom Menace
# 650   Star Wars: Episode I  The Phantom Menace
#
#                                          seen_EII  \
# 65    Star Wars: Episode II  Attack of the Clones
# 1004  Star Wars: Episode II  Attack of the Clones
# 650                                           NaN
#
#                                         seen_EIII  \
# 65    Star Wars: Episode III  Revenge of the Sith
# 1004  Star Wars: Episode III  Revenge of the Sith
# 650                                           NaN
#
#                                seen_EIV  \
# 65    Star Wars: Episode IV  A New Hope
# 1004  Star Wars: Episode IV  A New Hope
# 650                                 NaN
#
#                                            seen_EV  \
# 65    Star Wars: Episode V The Empire Strikes Back
# 1004  Star Wars: Episode V The Empire Strikes Back
# 650   Star Wars: Episode V The Empire Strikes Back
#
#                                       seen_EVI rank_EI rank_EII rank_EIII  \
# 65    Star Wars: Episode VI Return of the Jedi       1        2         3
# 1004  Star Wars: Episode VI Return of the Jedi       2        6         5
# 650   Star Wars: Episode VI Return of the Jedi       3        4         5
#
#      rank_EIV rank_EV rank_EVI            Han Solo      Luke Skywalker  \
# 65          4       5        6  Somewhat favorably  Somewhat favorably
# 1004        4       3        1      Very favorably      Very favorably
# 650         6       1        2      Very favorably      Very favorably
#
#      Princess Leia Organa    Anakin Skywalker  Obi Wan Kenobi  \
# 65     Somewhat favorably  Somewhat favorably  Very favorably
# 1004       Very favorably      Very favorably  Very favorably
# 650        Very favorably      Very favorably  Very favorably
#
#      Emperor Palpatine         Darth Vader  \
# 65    Unfamiliar (N/A)      Very favorably
# 1004    Very favorably  Somewhat favorably
# 650   Unfamiliar (N/A)  Somewhat favorably
#
#                                  Lando Calrissian  \
# 65    Neither favorably nor unfavorably (neutral)
# 1004                               Very favorably
# 650                                Very favorably
#
#                                         Boba Fett  \
# 65    Neither favorably nor unfavorably (neutral)
# 1004                               Very favorably
# 650                              Unfamiliar (N/A)
#
#                                             C-3P0               R2 D2  \
# 65    Neither favorably nor unfavorably (neutral)  Somewhat favorably
# 1004                               Very favorably      Very favorably
# 650                                Very favorably      Very favorably
#
#                                     Jar Jar Binks  \
# 65    Neither favorably nor unfavorably (neutral)
# 1004                               Very favorably
# 650                                Very favorably
#
#                                     Padme Amidala                Yoda  \
# 65    Neither favorably nor unfavorably (neutral)  Somewhat favorably
# 1004                               Very favorably      Very favorably
# 650                              Unfamiliar (N/A)      Very favorably
#
#            Which character shot first?  \
# 65    I don't understand this question
# 1004  I don't understand this question
# 650   I don't understand this question
#
#      Are you familiar with the Expanded Universe?  \
# 65                                             No
# 1004                                           No
# 650                                            No
#
#      Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 65                                                  NaN
# 1004                                                NaN
# 650                                                 NaN
#
#      Do you consider yourself to be a fan of the Star Trek franchise?  Gender  \
# 65                                                   No                  Male
# 1004                                                 No                Female
# 650                                                 Yes                Female
#
#         Age Household Income                         Education  \
# 65    18-29     $0 - $24,999  Some college or Associate degree
# 1004  18-29        $150,000+                   Bachelor degree
# 650   45-60              NaN                   Graduate degree
#
#      Location (Census Region)
# 65                    Pacific
# 1004       West North Central
# 650            South Atlantic

# %% [markdown]
# # America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)

# %% [markdown]
# _Original article available at [FiveThirtyEight](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/)_
#
# By [Walt Hickey](https://fivethirtyeight.com/contributors/walt-hickey/)
#
# Filed under [Movies](https://fivethirtyeight.com/tag/movies/)
#
# Get the data on [GitHub](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)

# %% [markdown]
# This week, I caught a sneak peek [of the X-Wing fighter](http://www.wired.com/2014/07/star-wars-episode-vii-x-wing/) from the new “Star Wars” films in production. The forthcoming movies — and the middling response to the most recent trilogy — provide a perfect excuse to examine some questions I’ve long wanted answers to: How many people are “Star Wars” fans? Does the rest of America realize that “The Empire Strikes Back” is clearly the best of the bunch? Which characters are most well-liked and most hated? And who shot first, Han Solo or Greedo?
#
# We ran a poll through [SurveyMonkey Audience](https://www.surveymonkey.com/mp/audience/), surveying 1,186 respondents from June 3 to 6 (the [data](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey) is available [on GitHub](https://github.com/fivethirtyeight/data)). Seventy-nine percent of those respondents said they had watched at least one of the “Star Wars” films. This question, incidentally, had a substantial difference by gender: 85 percent of men have seen at least one “Star Wars” film compared to 72 percent of women. Of people who have seen a film, men were also more likely to consider themselves a fan of the franchise: 72 percent of men compared to 60 percent of women.
#
# We then asked respondents which of the films they had seen. With 835 people responding, here’s the probability that someone has seen a given “Star Wars” film given that they have seen any Star Wars film:

# %% [markdown]
# !["Sol1"](/voc/data/have_seen_resized.png)

# %%
# We're going to fix the labels a bit so will create a mapping to the full names
# and have the full sort order
def genEpisodeNamesDF():
    # create the various mapping and order lists/dictionaries
    # return: list of episodes (in order), episode->name map, list of episode names (in order)
    episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
    names = {
        'EI' : 'The Phantom Menace', 'EII' : 'Attack of the Clones', 'EIII' : 'Revenge of the Sith', 
        'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'The Return of the Jedi'
    }

    # we're also going to use this order to sort, so names_l will now have our sort order
    return episodes, names, [names[ep] for ep in episodes]

episodes, namesDict, namesList = genEpisodeNamesDF()

# %%
# let's inspect what we've generated. These will be useful to you below
print("abbreviated list (sorted):\n  ",episodes)
print("\nmapping between abberviated names and full titles:\n  ",namesDict)
print("\nfull titles, sorted:\n  ",namesList)
# Out:
# abbreviated list (sorted):
#    ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
#
# mapping between abberviated names and full titles:
#    {'EI': 'The Phantom Menace', 'EII': 'Attack of the Clones', 'EIII': 'Revenge of the Sith', 'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI': 'The Return of the Jedi'}
#
# full titles, sorted:
#    ['The Phantom Menace', 'Attack of the Clones', 'Revenge of the Sith', 'A New Hope', 'The Empire Strikes Back', 'The Return of the Jedi']

# %%
# let's do some data pre-processing... recall that sw (star wars) has everything

def getSeenAtLeastOneDF(indf, eps):
    # input: indf the data file as formatted above
    # input: eps a list of episodes (movies)

    # returns a substet of the dataset
    
    # We want to only use those people who have seen at least one movie, let's get the people, toss NAs
    # and get the total count

    # find people who have at least on of the columns (seen_*) not NaN
    salo = indf.dropna(subset=['seen_' + ep for ep in eps],how='all')
    
    return(salo)

# %%
seenAtLeastOneDF = getSeenAtLeastOneDF(sw, episodes)
print("total who have seen at least one: ", len(seenAtLeastOneDF),"\nSample:")
display(seenAtLeastOneDF.sample(5))
# Out:
# total who have seen at least one:  835
# Sample:
#       RespondentID seen_any_movie  fan  \
# 484   3.290449e+09            Yes   No
# 1033  3.288626e+09            Yes  Yes
# 852   3.289540e+09            Yes  Yes
# 889   3.289453e+09            Yes  Yes
# 687   3.289924e+09            Yes  Yes
#
#                                        seen_EI  \
# 484                                        NaN
# 1033  Star Wars: Episode I  The Phantom Menace
# 852   Star Wars: Episode I  The Phantom Menace
# 889   Star Wars: Episode I  The Phantom Menace
# 687   Star Wars: Episode I  The Phantom Menace
#
#                                          seen_EII  \
# 484                                           NaN
# 1033                                          NaN
# 852   Star Wars: Episode II  Attack of the Clones
# 889   Star Wars: Episode II  Attack of the Clones
# 687   Star Wars: Episode II  Attack of the Clones
#
#                                         seen_EIII  \
# 484                                           NaN
# 1033                                          NaN
# 852   Star Wars: Episode III  Revenge of the Sith
# 889   Star Wars: Episode III  Revenge of the Sith
# 687   Star Wars: Episode III  Revenge of the Sith
#
#                                seen_EIV  \
# 484                                 NaN
# 1033                                NaN
# 852   Star Wars: Episode IV  A New Hope
# 889   Star Wars: Episode IV  A New Hope
# 687   Star Wars: Episode IV  A New Hope
#
#                                            seen_EV  \
# 484   Star Wars: Episode V The Empire Strikes Back
# 1033  Star Wars: Episode V The Empire Strikes Back
# 852   Star Wars: Episode V The Empire Strikes Back
# 889   Star Wars: Episode V The Empire Strikes Back
# 687   Star Wars: Episode V The Empire Strikes Back
#
#                                       seen_EVI rank_EI rank_EII rank_EIII  \
# 484   Star Wars: Episode VI Return of the Jedi       3        4         5
# 1033  Star Wars: Episode VI Return of the Jedi       3        4         5
# 852   Star Wars: Episode VI Return of the Jedi       6        5         3
# 889   Star Wars: Episode VI Return of the Jedi       1        3         2
# 687   Star Wars: Episode VI Return of the Jedi       6        5         4
#
#      rank_EIV rank_EV rank_EVI            Han Solo      Luke Skywalker  \
# 484         6       1        2      Very favorably      Very favorably
# 1033        6       1        2      Very favorably      Very favorably
# 852         2       1        4      Very favorably  Somewhat favorably
# 889         4       5        6  Somewhat favorably  Somewhat favorably
# 687         2       1        3      Very favorably      Very favorably
#
#                              Princess Leia Organa  \
# 484                                Very favorably
# 1033                               Very favorably
# 852   Neither favorably nor unfavorably (neutral)
# 889                            Somewhat favorably
# 687                                Very favorably
#
#                                  Anakin Skywalker      Obi Wan Kenobi  \
# 484                                           NaN      Very favorably
# 1033  Neither favorably nor unfavorably (neutral)  Somewhat favorably
# 852   Neither favorably nor unfavorably (neutral)  Somewhat favorably
# 889                                Very favorably  Somewhat favorably
# 687   Neither favorably nor unfavorably (neutral)  Somewhat favorably
#
#        Emperor Palpatine                                  Darth Vader  \
# 484                  NaN  Neither favorably nor unfavorably (neutral)
# 1033  Somewhat favorably                             Very unfavorably
# 852     Unfamiliar (N/A)                           Somewhat favorably
# 889       Very favorably                               Very favorably
# 687     Very unfavorably  Neither favorably nor unfavorably (neutral)
#
#                                  Lando Calrissian  \
# 484                                           NaN
# 1033  Neither favorably nor unfavorably (neutral)
# 852   Neither favorably nor unfavorably (neutral)
# 889   Neither favorably nor unfavorably (neutral)
# 687                            Somewhat favorably
#
#                                         Boba Fett  \
# 484                                           NaN
# 1033  Neither favorably nor unfavorably (neutral)
# 852   Neither favorably nor unfavorably (neutral)
# 889                                Very favorably
# 687   Neither favorably nor unfavorably (neutral)
#
#                                             C-3P0               R2 D2  \
# 484                                Very favorably      Very favorably
# 1033                               Very favorably      Very favorably
# 852   Neither favorably nor unfavorably (neutral)      Very favorably
# 889                                Very favorably  Somewhat favorably
# 687                            Somewhat favorably  Somewhat favorably
#
#                                     Jar Jar Binks  \
# 484                                           NaN
# 1033                               Very favorably
# 852                              Unfamiliar (N/A)
# 889   Neither favorably nor unfavorably (neutral)
# 687                              Very unfavorably
#
#                                     Padme Amidala                Yoda  \
# 484                                           NaN      Very favorably
# 1033  Neither favorably nor unfavorably (neutral)      Very favorably
# 852                              Unfamiliar (N/A)  Somewhat favorably
# 889                                Very favorably      Very favorably
# 687   Neither favorably nor unfavorably (neutral)      Very favorably
#
#            Which character shot first?  \
# 484   I don't understand this question
# 1033                            Greedo
# 852                                Han
# 889                                NaN
# 687                                Han
#
#      Are you familiar with the Expanded Universe?  \
# 484                                            No
# 1033                                           No
# 852                                           Yes
# 889                                           NaN
# 687                                           Yes
#
#      Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 484                                                 NaN
# 1033                                                NaN
# 852                                                 Yes
# 889                                                 NaN
# 687                                                  No
#
#      Do you consider yourself to be a fan of the Star Trek franchise?  Gender  \
# 484                                                  No                Female
# 1033                                                Yes                Female
# 852                                                 Yes                Female
# 889                                                 NaN                   NaN
# 687                                                 Yes                Female
#
#         Age   Household Income                         Education  \
# 484    > 60  $50,000 - $99,999                   Bachelor degree
# 1033  45-60                NaN  Some college or Associate degree
# 852   30-44       $0 - $24,999                   Graduate degree
# 889     NaN                NaN                               NaN
# 687   45-60  $50,000 - $99,999                   Graduate degree
#
#      Location (Census Region)
# 484                   Pacific
# 1033                  Pacific
# 852                   Pacific
# 889                       NaN
# 687                   Pacific

# %%
# for each movie, we're going to calculate the percents and generate a new data frame

def genSeenPercentDf(inpf, names=namesDict, names_l=namesList):
    # input: inpf - an input frame of the form output by getSeenAtLeastOneDF()
    # input: names - a dictionary of abbreviations to names
    # input: names_l - a list of all the movies in series order
    
    total = len(inpf)
    percs = []

    # loop over each column and calculate the number of people who have seen the movie
    # specifically, filter out the people who are *NaN* for a specific episode (e.g., ep_EII), count them
    # and divide by the percent
    for seen_ep in ['seen_' + ep for ep in episodes]:
        perc = len(inpf[~ pd.isna(inpf[seen_ep])]) / total
        percs.append(perc)

    # at this point percs is holding our percentages

    # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
    tuples = list(zip([names[ep] for ep in episodes],percs))
    seen_per_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])
    return(seen_per_df)

# %%
seenPerMovieDF = genSeenPercentDf(seenAtLeastOneDF)

# %%
# let's see what's inside
seenPerMovieDF
# Out:
#                       Name  Percentage
# 0       The Phantom Menace    0.805988
# 1     Attack of the Clones    0.683832
# 2      Revenge of the Sith    0.658683
# 3               A New Hope    0.726946
# 4  The Empire Strikes Back    0.907784
# 5   The Return of the Jedi    0.883832

# %%
def genPercentVis(indf, names_l=namesList):
    # input: indf, the dataframe as seen_per_df
    # input: names_l - a list of all the movies in series order (default namesList)
    # output: simple altair bar chart
    
    # ok, time to make the chart... let's make a bar chart (use mark_bar)
    bars = alt.Chart(indf).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Percentage',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(tickCount=5, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=names_l
        )
    )

    # at this point we don't really have a great plot (it's missing the annotations, titles, etc.)
    return(bars)

seenPerMovieVis = genPercentVis(seenPerMovieDF)

# %%
# display it
seenPerMovieVis
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
def augmentPercentVis(base):
    # input: base (the base vis, i.e., bars as above)
    # we're going to overlay the text with the percentages, so let's make another visualization
    # that's just text labels


    text = base.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
    ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Percentage:Q',format='.0%')
    )

    # finally, we're going to combine the bars and the text and do some styling
    seen_movies = (text + base).configure_mark(
        # we don't love the blue
        color='#008fd5'
    ).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=180
    ).properties(
        # add a title
        title="Which 'Star Wars' Movies Have you Seen?"
    )

    return(seen_movies)

# note that we are NOT formatting this in the Five Thirty Eight Style yet... we'll leave that to you to figure out

# %%
# let's see it
augmentPercentVis(seenPerMovieVis)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# So we can see that “Star Wars: Episode V — The Empire Strikes Back” is the film seen by the most number of people, followed by “Star Wars: Episode VI — Return of the Jedi.” Appallingly, more people reported seeing “Star Wars: Episode I — The Phantom Menace” than the original “Star Wars” (renamed “Star Wars: Episode IV — A New Hope”).
#
# So, which movie is the best? We asked the subset of 471 respondents who indicated they have seen every “Star Wars” film to rank them from best to worst. From that question, we calculated the share of respondents who rated each film as their favorite.

# %% [markdown]
# !["Sol1"](/voc/data/best_movie_article_resized.png)
#
#
# ** Homework note: Click [here](/voc/data/best_movie.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.1 What's the best 'Star Wars' movie? Recreate the above image using altair (10 Points)
#
# Recreate the image above using Altair. Match the "538" style as best you can (hint: look at the altair lab at the start of the semester). We expect you to *at least* match the [our version](best_movie.png) of the chart that was created in Altair.

# %%
# Recreate this image using Altair
# match the "538 style" as best you can (hint: look at the altair lab at the start of the semester)

def genBestVis(inpf,eps, names=namesDict, names_l=namesList):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    # YOUR CODE HERE

    ### HELPER FUNCTIoN: Generate % of favorite film
    def genRankPercentDf(inpf, names=namesDict, names_l=namesList):
        # input: inpf - an input frame of the form output by getSeenAtLeastOneDF()
        # input: names - a dictionary of abbreviations to names
        # input: names_l - a list of all the movies in series order
        
        total = len(inpf)
        percs = []
    
        # loop over each column and calculate the number of people who have seen the movie
        # specifically, filter out the people who are *NaN* for a specific episode (e.g., ep_EII), count them
        # and divide by the percent
        for rank_ep in ['rank_' + ep for ep in episodes]:
            perc = len(inpf[inpf[rank_ep] == '1']) / total
            percs.append(perc)
    
        # at this point percs is holding our percentages
    
        # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
        tuples = list(zip([names[ep] for ep in episodes],percs))
        seen_per_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])
        return(seen_per_df)

    #### FILTER FOR people who have seen all films
    for seen_ep in ['seen_' + ep for ep in episodes]:
        inpf = inpf[~ pd.isna(inpf[seen_ep])]
    
    output = genRankPercentDf(inpf,names, names_l).round(2)

    # ok, time to make the chart... let's make a bar chart (use mark_bar)
    base = alt.Chart(output).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Percentage',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(tickCount=5, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=names_l
        )
    )

    text = base.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
    ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Percentage:Q',format='.0%')
    )

    # finally, we're going to combine the bars and the text and do some styling
    seen_movies = (text + base).configure_mark(
        # we don't love the blue
        color='#008fd5'
    ).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=180
    ).properties(
        # add a title
        title=alt.Title(text = "What's the best 'Star Wars' Moive?", align = 'left', anchor = 'start', fontSize = 24, 
                        subtitle = 'Of 471 respondents who have seen all 6 films')
    )
        
    return seen_movies

# %%
# test your code
genBestVis(sw,episodes)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# ## Make sure to *style* your visualization to match the original the best you can

# %% [markdown]
# We can also drill down and find out, generally, how people rate the films. Overall, fans broke into two camps: those who preferred the original three movies and those who preferred the three prequels. People who said “The Empire Strikes Back” was their favorite were also likely to rate “A New Hope” and “Return of the Jedi” higher as well. Those who rated “The Phantom Menace” as the best film were more likely to rate prequels higher.
#
# This chart shows how often each film was rated in the top third (best or second-best), the middle third (third or fourth) or the bottom third (second-worst or worst). It’s a more nuanced take on the series:

# %% [markdown]
# !["Sol1"](/voc/data/how_rate_resized.png)
#
# ** Homework note: Click [here](/voc/data/people_rate.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.2 How people rate the 'Star Wars' movie? Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)

def genRateVis(inpf,eps, names=namesDict, names_l=namesList):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
    #### FILTER FOR people who have seen all films
    for seen_ep in ['seen_' + ep for ep in episodes]:
        inpf = inpf[~ pd.isna(inpf[seen_ep])]

    def genRankPercentDf(inpf, third_name, third_group, names=namesDict, names_l=namesList):
        total = len(inpf)
        percs = []
    
        for rank_ep in ['rank_' + ep for ep in episodes]:
            perc = len(inpf[inpf[rank_ep].isin(third_group)]) / total
            percs.append(perc)
    
        # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
        tuples = list(zip([names[ep] for ep in episodes],percs))
        seen_per_df = pd.DataFrame(tuples, columns = ['Name', third_name])
        return(seen_per_df)

    # generate third buckets
    third_names = ['Top third', 'Middle third','Bottom third']
    third_groups = [['1','2'],['3','4'],['5','6']]
    third_dfs = []
    # generate data and join it together into 1 table
    for i in range(len(third_names)):
        third_dfs.append(genRankPercentDf(inpf, third_names[i], third_groups[i], names, names_l))
    output = pd.merge(pd.merge(third_dfs[0], third_dfs[1], on = 'Name'), third_dfs[2], on = 'Name').round(2)
    
    ### TOP THiRD ###
    
    top_third = alt.Chart(output[['Name', 'Top third']]).mark_bar(color = '#77AB43', size=20).encode(
        x=alt.X('Top third:Q',axis=alt.Axis(titleFontSize = 14, titleAlign = 'left', titleAnchor = 'start', orient='top',
                                            grid = False, labels = False, ticks = False, domain = False)),
        y=alt.Y('Name:N',axis=alt.Axis(labelFontSize = 14, tickCount=5, title=''),sort=names_l)
    )

    top_third_text = top_third.mark_text(
        align='left',
        baseline='middle',
        dx=3,  # Nudges text to right so it doesn't appear on top of the bar
        color = '#77AB43'
    ).encode(text=alt.Text('Top third',format='.0%'))

    ### MIDDLE THIRD ###
        
    middle_third = alt.Chart(output[['Name', 'Middle third']]).mark_bar(color = '#008fd5', size=20).encode(
        x=alt.X('Middle third:Q',axis=alt.Axis(titleFontSize = 14,titleAlign = 'left', titleAnchor = 'start', orient='top', 
                                               grid = False, labels = False, ticks = False, domain = False)),
        y=alt.Y('Name:N',axis=None,sort=names_l)
    )

    middle_third_text = middle_third.mark_text(
        align='left',
        baseline='middle',
        dx=3,  # Nudges text to right so it doesn't appear on top of the bar
        color = '#008fd5'
    ).encode(text=alt.Text('Middle third',format='.0%'))

    ### BOTTOM THIRD

    bottom_third = alt.Chart(output[['Name', 'Bottom third']]).mark_bar(color = 'red', size=20).encode(
        x=alt.X('Bottom third:Q',axis=alt.Axis(titleFontSize = 14, titleAlign = 'left', titleAnchor = 'start',
                                               orient='top', grid = False, labels = False, ticks = False, domain = False)),
        y=alt.Y('Name:N',axis=None,sort=names_l)
    )

    bottom_third_text = bottom_third.mark_text(
        align='left',
        baseline='middle',
        dx=3,  # Nudges text to right so it doesn't appear on top of the bar
        color = 'red'
    ).encode(text=alt.Text('Bottom third',format='.0%'))
    width_scaler = 0.5
    top_third_complete = (top_third + top_third_text).properties(width=int(64 * width_scaler) ,height=180)
    middle_third_complete = (middle_third + middle_third_text).properties(width=int(41 * width_scaler),height=180)
    bottom_third_complete = (bottom_third + bottom_third_text).properties(width=int(57 * width_scaler),height=180)

    full_comb = alt.hconcat( top_third_complete, middle_third_complete, bottom_third_complete, spacing = 30)
    full_comb = full_comb.properties(title=alt.Title(text = "How people rate the 'Star Wars' Movies", align = 'left', anchor = 'start', fontSize = 24, 
                        subtitle = ['How often each film was rated in the top, middle and bottom third','(by 471 respondents who have seen all 6 films).'])
                                    ).configure_view(strokeWidth=0).configure_scale(bandPaddingInner=0.2).configure_concat(spacing=3)
    return full_comb

# %%
# let's check our solution
genRateVis(sw,episodes)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# Finally, we took a boilerplate format used by political favorability polls — “Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her” — and asked respondents to rate characters in the series.

# %% [markdown]
# !["Sol1"](/voc/data/char_ranking_resized.png)
#
#
# ** Homework note. Here's an example solution generated in Altair:
# !["Sol1"](/voc/data/people_rate_s.png)
#
# Be careful here in what you're dividing by to get the totals for each character.

# %% [markdown]
# ### 2.3 Star Wars' Characters Favorability Ratings. Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)

def genFavorabilityVis(inpf):
    # input: inpf, the star wars dataset (as defined at top of file)
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
    #### FILTER FOR people who have seen all films
    
    
    def genRankPercentDf(inpf, name, chart_titles, chart_groups):
        percs = []
    
        subdf = inpf[name]
        total = subdf.value_counts().to_frame()[name].sum()
        counts = subdf.value_counts().to_frame()
        #print(counts)
        percents = []

        for i in range(len(chart_titles)):
            pct = float(counts.loc[chart_groups[i],:].sum() / total)
            percents.append(pct)
    
        # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
        tuples = list(zip(chart_titles,percents))
        seen_per_df = pd.DataFrame(tuples, columns = ['Favorability', name])
        return(seen_per_df)

    # generate third buckets
    names = ['Luke Skywalker', 'Han Solo', 'Princess Leia Organa', 'Obi Wan Kenobi', 'Yoda', 'R2 D2' , 'C-3P0' ,
             'Anakin Skywalker' ,'Darth Vader' ,'Lando Calrissian' ,'Padme Amidala' ,'Boba Fett' ,'Emperor Palpatine' ,'Jar Jar Binks']
    chart_titles = ['Favorable', 'Neutral','Unfavorable','Unfamiliar']
    chart_groups = [['Very favorably', 'Somewhat favorably'],['Neither favorably nor unfavorably (neutral)'],['Somewhat unfavorably','Very unfavorably'],['Unfamiliar (N/A)']]
    name_dfs = []
    # generate data and join it together into 1 table
    for i in range(len(names)):
        name_dfs.append(genRankPercentDf(inpf, names[i], chart_titles, chart_groups))
    # append all groups into output
    output = None
    for i in range(len(names)):
        if output is None:
            output = name_dfs[i]
        else:
            output = pd.merge(output, name_dfs[i], on = 'Favorability')
    output = output.set_index('Favorability').transpose().reset_index().rename(columns = {'index':'Name'}).round(2)

    ### Favorable ###
    
    favorable = alt.Chart(output[['Name', 'Favorable']]).mark_bar(color = '#77AB43', size=20).encode(
        x=alt.X('Favorable:Q',axis=alt.Axis(titleFontSize = 14, titleAlign = 'left', titleAnchor = 'start', orient='top',
                                            grid = False, labels = False, ticks = False, domain = False)),
        y=alt.Y('Name:N',axis=alt.Axis(labelFontSize = 14, tickCount=5, title=''),sort=names)
    )

    favorable_text = favorable.mark_text(
        align='left',
        baseline='middle',
        dx=3,  # Nudges text to right so it doesn't appear on top of the bar
        color = '#77AB43'
    ).encode(text=alt.Text('Favorable',format='.0%'))

    ### Neutral ###
        
    neutral = alt.Chart(output[['Name', 'Neutral']]).mark_bar(color = '#008fd5', size=20).encode(
        x=alt.X('Neutral:Q',axis=alt.Axis(titleFontSize = 14, titleAlign = 'left', titleAnchor = 'start', orient='top',
                                            grid = False, labels = False, ticks = False, domain = False)),
        y=alt.Y('Name:N',axis=None,sort=names)
    )

    neutral_text = neutral.mark_text(
        align='left',
        baseline='middle',
        dx=3,  # Nudges text to right so it doesn't appear on top of the bar
        color = '#008fd5'
    ).encode(text=alt.Text('Neutral',format='.0%'))

    ### Unfavorable

    unfavorable = alt.Chart(output[['Name', 'Unfavorable']]).mark_bar(color = 'red', size=20).encode(
        x=alt.X('Unfavorable:Q',axis=alt.Axis(titleFontSize = 14, titleAlign = 'left', titleAnchor = 'start', orient='top',
                                            grid = False, labels = False, ticks = False, domain = False)),
        y=alt.Y('Name:N',axis=None,sort=names)
    )

    unfavorable_text = unfavorable.mark_text(
        align='left',
        baseline='middle',
        dx=3,  # Nudges text to right so it doesn't appear on top of the bar
        color = 'red'
    ).encode(text=alt.Text('Unfavorable',format='.0%'))

    ### Unfamiliar

    unfamiliar = alt.Chart(output[['Name', 'Unfamiliar']]).mark_bar(color = 'gray', size=20).encode(
        x=alt.X('Unfamiliar:Q',axis=alt.Axis(titleFontSize = 14, titleAlign = 'left', titleAnchor = 'start', orient='top',
                                            grid = False, labels = False, ticks = False, domain = False)),
        y=alt.Y('Name:N',axis=None,sort=names)
    )

    unfamiliar_text = unfamiliar.mark_text(
        align='left',
        baseline='middle',
        dx=3,  # Nudges text to right so it doesn't appear on top of the bar
        color = 'gray'
    ).encode(text=alt.Text('Unfamiliar',format='.0%'))

    chart_height = 350
    width_multiplier = 1

    favorable_complete = (favorable + favorable_text).properties(width=round(93 * width_multiplier),height=chart_height)
    neutral_complete = (neutral + neutral_text).properties(width= round(31 * width_multiplier),height=chart_height)
    unfavorable_complete = (unfavorable + unfavorable_text).properties(width= round(37 * width_multiplier),height=chart_height)
    unfamiliar_complete = (unfamiliar + unfamiliar_text).properties(width= round(20 * width_multiplier),height=chart_height)

    full_comb = alt.hconcat( favorable_complete, neutral_complete, unfavorable_complete, unfamiliar_complete, spacing = 30)
    full_comb = full_comb.properties(title=alt.Title(text = "'Star Wars' Character Favorability Ratings", align = 'left', anchor = 'start', fontSize = 24, 
                        subtitle = ['By 834 respondents'], subtitleFontSize = 14)).configure_view(strokeWidth=0).configure_scale(bandPaddingInner=0.2).configure_concat(spacing=3)
    return full_comb

# %%
# let's test the solution
genFavorabilityVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# !["Sol1"](/voc/data/shot_first_article_resized.png)
#
#
# ** Homework note: Click [here](/voc/data/shot_first.png) to see a version of this plot generated in Altair. You may find that you don't get 834 rows (as 538 did) but the percents should still work.

# %% [markdown]
# ### 2.4 Who shot first? Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)
from textwrap import wrap

def genFirstShotVis(inpf):
    # input: inpf, the star wars dataset
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
    ### HELPER FUNCTIoN: Generate % of favorite film
    def genRankPercentDf(inpf, name, chart_titles, chart_groups):
        percs = []
    
        subdf = inpf[name]
        total = subdf.value_counts().to_frame()[name].sum()
        counts = subdf.value_counts().to_frame()
        #print(counts)
        percents = []

        for i in range(len(chart_titles)):
            pct = float(counts.loc[chart_groups[i],:].sum() / total)
            percents.append(pct)
    
        # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
        tuples = list(zip(chart_titles,percents))
        seen_per_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])
        return(seen_per_df)

        
    names = ['Han','Greedo',"I don't understand this question"]
    output = genRankPercentDf(inpf,'Which character shot first?',names, names).round(2)
    output['Name'] = output['Name'].apply(wrap, args=[20])
    ### Manually override I don't  understand's label
    
    # ok, time to make the chart... let's make a bar chart (use mark_bar)
    base = alt.Chart(output).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Percentage',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(labelFontSize = 14, tickCount=5, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=names
        )
    )

    text = base.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
    ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Percentage:Q',format='.0%')
    )

    # finally, we're going to combine the bars and the text and do some styling
    seen_movies = (text + base).configure_mark(
        # we don't love the blue
        color='#008fd5'
    ).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=100
    ).properties(
        # add a title
        title=alt.Title(text = "Who Shot First?", align = 'left', anchor = 'start', fontSize = 24, 
                        subtitle = 'According to 834 respondents', subtitleFontSize = 14)
    )
        
    return seen_movies

# %%
# test our solution
genFirstShotVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# ### 2.5 Make your own (35 points total - 20 for implementation, 15 for justification)

# %% [markdown]
# Reading through the article, identify some aspect of the story that would benefit from an extra visualization (you can imagine extending the article if it helps). We would like for you to create two versions of this hypothetical visualization.  You should be able to convincingly argue that one visualization is better than the other.
#
# Note: The two visualizations should use different marks and at least some of the encodings should be different. If you're struggling with coming up with two really different representations, your visualization may simply be too simple. Try to add additional columns/comparisons.

# %%
sw.head(5)
# Out:
#    RespondentID seen_any_movie  fan                                   seen_EI  \
# 1  3.292880e+09            Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 2  3.292880e+09             No  NaN                                       NaN
# 3  3.292765e+09            Yes   No  Star Wars: Episode I  The Phantom Menace
# 4  3.292763e+09            Yes  Yes  Star Wars: Episode I  The Phantom Menace
# 5  3.292731e+09            Yes  Yes  Star Wars: Episode I  The Phantom Menace
#
#                                       seen_EII  \
# 1  Star Wars: Episode II  Attack of the Clones
# 2                                          NaN
# 3  Star Wars: Episode II  Attack of the Clones
# 4  Star Wars: Episode II  Attack of the Clones
# 5  Star Wars: Episode II  Attack of the Clones
#
#                                      seen_EIII  \
# 1  Star Wars: Episode III  Revenge of the Sith
# 2                                          NaN
# 3  Star Wars: Episode III  Revenge of the Sith
# 4  Star Wars: Episode III  Revenge of the Sith
# 5  Star Wars: Episode III  Revenge of the Sith
#
#                             seen_EIV  \
# 1  Star Wars: Episode IV  A New Hope
# 2                                NaN
# 3                                NaN
# 4  Star Wars: Episode IV  A New Hope
# 5  Star Wars: Episode IV  A New Hope
#
#                                         seen_EV  \
# 1  Star Wars: Episode V The Empire Strikes Back
# 2                                           NaN
# 3                                           NaN
# 4  Star Wars: Episode V The Empire Strikes Back
# 5  Star Wars: Episode V The Empire Strikes Back
#
#                                    seen_EVI rank_EI rank_EII rank_EIII  \
# 1  Star Wars: Episode VI Return of the Jedi       3        2         1
# 2                                       NaN     NaN      NaN       NaN
# 3                                       NaN       1        2         3
# 4  Star Wars: Episode VI Return of the Jedi       5        6         1
# 5  Star Wars: Episode VI Return of the Jedi       5        4         6
#
#   rank_EIV rank_EV rank_EVI            Han Solo      Luke Skywalker  \
# 1        4       5        6      Very favorably      Very favorably
# 2      NaN     NaN      NaN                 NaN                 NaN
# 3        4       5        6  Somewhat favorably  Somewhat favorably
# 4        2       4        3      Very favorably      Very favorably
# 5        2       1        3      Very favorably  Somewhat favorably
#
#   Princess Leia Organa      Anakin Skywalker      Obi Wan Kenobi  \
# 1       Very favorably        Very favorably      Very favorably
# 2                  NaN                   NaN                 NaN
# 3   Somewhat favorably    Somewhat favorably  Somewhat favorably
# 4       Very favorably        Very favorably      Very favorably
# 5   Somewhat favorably  Somewhat unfavorably      Very favorably
#
#     Emperor Palpatine         Darth Vader  \
# 1      Very favorably      Very favorably
# 2                 NaN                 NaN
# 3    Unfamiliar (N/A)    Unfamiliar (N/A)
# 4  Somewhat favorably      Very favorably
# 5    Very unfavorably  Somewhat favorably
#
#                               Lando Calrissian             Boba Fett  \
# 1                             Unfamiliar (N/A)      Unfamiliar (N/A)
# 2                                          NaN                   NaN
# 3                             Unfamiliar (N/A)      Unfamiliar (N/A)
# 4                           Somewhat favorably  Somewhat unfavorably
# 5  Neither favorably nor unfavorably (neutral)        Very favorably
#
#                 C-3P0               R2 D2     Jar Jar Binks  \
# 1      Very favorably      Very favorably    Very favorably
# 2                 NaN                 NaN               NaN
# 3    Unfamiliar (N/A)    Unfamiliar (N/A)  Unfamiliar (N/A)
# 4      Very favorably      Very favorably    Very favorably
# 5  Somewhat favorably  Somewhat favorably  Very unfavorably
#
#         Padme Amidala                Yoda       Which character shot first?  \
# 1      Very favorably      Very favorably  I don't understand this question
# 2                 NaN                 NaN                               NaN
# 3    Unfamiliar (N/A)    Unfamiliar (N/A)  I don't understand this question
# 4      Very favorably      Very favorably  I don't understand this question
# 5  Somewhat favorably  Somewhat favorably                            Greedo
#
#   Are you familiar with the Expanded Universe?  \
# 1                                          Yes
# 2                                          NaN
# 3                                           No
# 4                                           No
# 5                                          Yes
#
#   Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 1                                                 No
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                 No
#
#   Do you consider yourself to be a fan of the Star Trek franchise? Gender  \
# 1                                                 No                 Male
# 2                                                Yes                 Male
# 3                                                 No                 Male
# 4                                                Yes                 Male
# 5                                                 No                 Male
#
#      Age     Household Income                         Education  \
# 1  18-29                  NaN                High school degree
# 2  18-29         $0 - $24,999                   Bachelor degree
# 3  18-29         $0 - $24,999                High school degree
# 4  18-29  $100,000 - $149,999  Some college or Associate degree
# 5  18-29  $100,000 - $149,999  Some college or Associate degree
#
#   Location (Census Region)
# 1           South Atlantic
# 2       West South Central
# 3       West North Central
# 4       West North Central
# 5       West North Central

# %%
# YOUR CODE HERE
def genfandomVis(inpf):
    # input: inpf, the star wars dataset
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
    ### HELPER FUNCTIoN: Generate % of favorite film
    def genRankPercentDf(inpf, name, chart_titles, chart_order, gender_group):
        percs = []
    
        subdf = inpf[name]
        total = subdf.value_counts().to_frame()[name].sum()
        counts = subdf.value_counts().to_frame()
        #print(counts)
        percents = []

        for i in range(len(chart_titles)):
            pct = float(counts.loc[chart_titles[i],:].sum() / total)
            percents.append(pct)
    
        # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
        tuples = list(zip(chart_titles, chart_order, [gender_group] * len(percents), percents))
        seen_per_df = pd.DataFrame(tuples, columns = ['Fandom', 'Fandom_Order', 'Group', 'Percentage'])
        return(seen_per_df)

    def encode_fandom(row):
        if row['fan'] == 'Yes' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] == 'Yes':
            return 'Fan of Both'
        elif row['fan'] == 'No' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] == 'No':
            return 'Fan of Neither'
        elif row['fan'] == 'Yes' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] != 'Yes':
            return 'Star Wars Fan'
        elif row['fan'] != 'Yes' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] == 'Yes':
            return 'Star Trek Fan'
        else:
            return None

    

    inpf['Fandom'] = inpf.apply(encode_fandom, axis = 1) # Step 1:  Create our fandom variable
    
    ## STEP w: Filter for gender values != NA
    ### THIS DROPS most non-responses and lets us get percentages for each gender group
    inpf = inpf[~inpf['Gender'].isna()]
    
    

    gender_groups = ['Combined','Male','Female']
    names = ['Fan of Neither','Star Trek Fan','Fan of Both',"Star Wars Fan"]
    names_order = [1,2,3,4]
    outputs = []
    for gender_group in gender_groups:
        if gender_group == 'Combined':
            outputs.append( genRankPercentDf(inpf,'Fandom',names, names_order, gender_group).round(2))
        else:
            outputs.append( genRankPercentDf(inpf[inpf['Gender']==gender_group],'Fandom',names, names_order, gender_group).round(2))
            
    output = pd.concat(outputs)
    
    # ok, time to make the chart... let's make a bar chart (use mark_bar)
    base = alt.Chart(output).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X('Percentage',stack='center', axis=None),
        y=alt.Y('Group:N',axis=alt.Axis(labelFontSize = 14, tickCount=5, title=''),sort=gender_groups),

        order = alt.Order('Fandom_Order', sort='ascending')
    )

    out_chart = base.encode(        color = alt.Color('Fandom:N', 
                          sort = ['Fan of Neither', 'Star Trek Fan', 'Fan of Both','Star Wars Fan'], 
                          scale=alt.Scale(domain=['Fan of Neither', 'Star Trek Fan', 'Fan of Both','Star Wars Fan'], range=['gray', '#D60000', '#A268F8','#7993FF'])))

    text = base.mark_text(
        align='right',
        baseline='middle',
        dx=-5,  # Nudges text to right so it doesn't appear on top of the bar
        color = 'black'
    ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Percentage:Q',format='.0%')
    )

    # finally, we're going to combine the bars and the text and do some styling
    seen_movies = (out_chart + text).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=100
    ).properties(
        # add a title
        title=alt.Title(text = "Do different genders prefer different fandoms?", align = 'left', anchor = 'start', fontSize = 24, 
                        subtitle = 'According to 1046 respondents with an entered gender and responed Yes or No to at least 1 fandom question', subtitleFontSize = 14)
    )
        
    return seen_movies

genfandomVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
# YOUR CODE HERE
# YOUR CODE HERE
def genfandomVisBad(inpf):
    # input: inpf, the star wars dataset
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
    ### HELPER FUNCTIoN: Generate % of favorite film
    def genRankPercentDf(inpf, name, chart_titles, chart_order, gender_group):
        percs = []
    
        subdf = inpf[name]
        total = subdf.value_counts().to_frame()[name].sum()
        counts = subdf.value_counts().to_frame()
        #print(counts)
        percents = []

        for i in range(len(chart_titles)):
            pct = float(counts.loc[chart_titles[i],:].sum())
            percents.append(pct)
    
        # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
        tuples = list(zip(chart_titles, chart_order, [gender_group] * len(percents), percents))
        seen_per_df = pd.DataFrame(tuples, columns = ['Fandom', 'Fandom_Order', 'Group', 'Number'])
        return(seen_per_df)

    def encode_fandom(row):
        if row['fan'] == 'Yes' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] == 'Yes':
            return 'Fan of Both'
        elif row['fan'] == 'No' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] == 'No':
            return 'Fan of Neither'
        elif row['fan'] == 'Yes' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] != 'Yes':
            return 'Star Wars Fan'
        elif row['fan'] != 'Yes' and row['Do you consider yourself to be a fan of the Star Trek franchise?'] == 'Yes':
            return 'Star Trek Fan'
        else:
            return None

    

    inpf['Fandom'] = inpf.apply(encode_fandom, axis = 1) # Step 1:  Create our fandom variable
    
    ## STEP w: Filter for gender values != NA
    ### THIS DROPS most non-responses and lets us get percentages for each gender group
    inpf = inpf[~inpf['Gender'].isna()]
    
    

    gender_groups = ['Male','Female']
    names = ['Fan of Neither','Star Trek Fan','Fan of Both',"Star Wars Fan"]
    names_order = [1,2,3,4]
    outputs = []
    for gender_group in gender_groups:
         outputs.append( genRankPercentDf(inpf[inpf['Gender']==gender_group],'Fandom',names, names_order, gender_group).round(0))
            
    output = pd.concat(outputs)
    output['Percentage'] =  (output['Number'] /  output['Number'].sum()).round(2)
    output['radius'] = output['Group'].apply(lambda x:  200 if x == 'Male' else 100)
    output['Description'] = output['Group'] + ' ' + output['Fandom']
    
    # ok, time to make the chart... let's make a bar chart (use mark_bar)
    base = alt.Chart(output).encode(
        # encode x as the percent, and hide the axis
        theta=alt.Theta('Number:Q').stack('normalize'),
        radius=alt.Radius('radius:Q'),
        order = alt.Order('Group', sort='ascending'),
        color = alt.Color('Fandom:N', 
                          sort = ['Fan of Neither', 'Star Trek Fan', 'Fan of Both','Star Wars Fan'], 
                          scale=alt.Scale(domain=['Fan of Neither', 'Star Trek Fan', 'Fan of Both','Star Wars Fan'], range=['gray', '#D60000', '#A268F8','#7993FF']))
    )

    chart = base.mark_arc(stroke="#fff", strokeWidth=2, innerRadius=0)


    text = base.mark_text(radiusOffset=-25, fill="black").encode(
        # we'll use the percentage as the text
        text=alt.Text('Percentage:Q',format='.0%')
    )

    # finally, we're going to combine the bars and the text and do some styling
    seen_movies = (chart + text).properties(
        # set the dimensions of the visualization
        width=500,
        height=500
    ).properties(
        # add a title
        title=alt.Title(text = "Do different genders prefer different fandoms?", align = 'left', anchor = 'start', fontSize = 24, 
                        subtitle = ['According to 1046 respondents with an entered gender and responed Yes or No to at least 1 fandom question',
                                    'inner radius is for womern, outer radius is for men'], subtitleFontSize = 14)
    )
        
    return seen_movies

genfandomVisBad(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# #### Justification
# *Provide your justification here* to argue why your "better" version is actually better. Make sure to defend this based on expressiveness and effectiveness as well as perceptual arguments.

# %% [markdown]
# The Bar chart version of ‘Do different genders prefer different fandoms?’ is a better chart  because it is more expressive of gender percentile breakdowns and more effective to compare fandom composition than the pie chart version.
#
# The bar chart is more expressive as it has 3 bars, one for the breakdown of the combined group, and then one for Male respondents and one for female respondents.  This is effective as it answers the question ‘what is the fandom breakdown?’ for all responses, Male responses, and Female responses.  The pie chart allows you to read the combined response if you add up all the percentages and you can roughly see the breakdown of each gender, but it is not clearly stated what the fandom breakdown of each gender is on the pie chart, thus making it less expressive.
#
# On top of being more expressive, the bar chart is more effective, as the bar chart lets you compare easily the proportion of respondents in each fandom group to each other and to the overall proportion of respondents more easily than the pie chart allows you to, as the bar length is easier to compare than the theta of each curve.
#
# For an example, it is easier to tell that Male responses are more likely to be a fan of both and female responses are more likely to be a fan of neither much more easily in the bar chart as the pieces are all ordered and displayed on the same scale.  The different genders being encoded in pie chart radius to create the inner pie makes it more difficult to compare proportion of responses between groups due to the different sizes of the arcs.  Female  proportions will appear smaller even if they are the same % of the total because their arc radius is smaller, thus making it more difficult to understand.
