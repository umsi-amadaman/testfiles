# %% [markdown]
# # Information Visualization I
# ## School of Information, University of Michigan
#
# ## Week 3:
# - Perception / Cognition
#
# ## Assignment Overview
# ### This assignment's objectives include:
#
# - Review, refect, and apply the concepts of the perception pipeline. Justify how different encodings impact the effectiveness of a visualization depending on the human perception process.
#
# !["Drawing"](/voc/data/preattentive_resized.png)
#
# <p style="text-align: center;"> Preattentive Processing </p>
#
# - Recreate visualizations and propose new and alternative visualizations using [Altair](https://altair-viz.github.io/)
#
# ### The total score of this assignment will be 100 points consisting of:
# - Case study reflection: America's Favorite 'Star Wars' Movies (And Least Favorite Characters) (25 points)
# - Altair programming exercise (75 points)
#
# ### Resources:
# - Article by [FiveThirtyEight](https://fivethirtyeight.com) available  [online](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) (Hickey, 2014)
# - Datasets from FiveThirtyEight, we have downloaded a subset of this data in the folder [./assets](assets)
#     - The original dataset can be found at [FiveThirtyEight Star Wars Survey](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
#
# ### Important notes:
# 1) There will be a couple of places where the numbers you get when you select rows may be a little different than 538, but the percents should still work (e.g., 828 instead of 834). You'll see this in our examples. If you can somehow get the data to match exactly, that's great too.
#
# 2) A lot of this assignment will be based on building "compound" charts. Using the wrong strategy will mean that you are spending a lot of time "cleaning up" charts. We strongly suggest reading through (and understanding) the Altair documentation [on this](https://altair-viz.github.io/user_guide/compound_charts.html).
#
# 3) Grading for this assignment is entirely done by a human grader. They will be running tests on the functions we ask you to create. This means there is no autograding (submitting through the autograder will result in an error). You are expected to test and validate your own code.
#
# 4) Keep your notebooks clean and readable. If your code is highly messy or inefficient you will get a deduction.
#
# 5) Follow the instructions for submission on Coursera. You will be providing us a generated link to a read-only version of your notebook and a PDF. When turning in your PDF, please use the File -> Print -> Save as PDF option ***from your browser***. Do ***not*** use the File->Download as->PDF option. Complete instructions for this are under Resources in the Coursera page for this class. If you're having trouble with printing, take a look at [this video](https://youtu.be/PiO-K7AoWjk).

# %% [markdown]
# ## Part 1. Perception and Cognition (25 points)
# Read the article ["America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters),"](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) and answer the following questions:

# %% [markdown]
# ### 1.1 List the different data types in the following visualizations and their encodings (10 points)
# Look at the following visualizations. For each, list the variable, their type, and the encoding used.
#
# !["How rate visualization"](/voc/data/how_rate_resized.png)
# !["Have seen visualization"](/voc/data/have_seen_resized.png)
#
# Use the following table for each variable (indicate which vis each came from):
# * variable name, variable type (e.g., ordinal, nominal, etc.), variable encoding (e.g., color, x-position, etc.)
#
# For example, if you [look at this visualization](https://altair-viz.github.io/gallery/scatter_tooltips.html) one row in our table below would be: Horsepower, quantitative, x-position.

# %% [markdown]
# _1.1 Answer_
#
# *Use as many rows as you need*
#
# How People Rate the 'Star Wars' Movies
#
# | Variable name| Variable Type (Ordinal/Nominal/Quantitative) | Variable encoding (color, x-position, etc.) |
# | --- | --- | --- |
# |  *movie title * | *nominal * | * Y - Position* |
# |  *Rating group* | *ordinal* | *Color hue* |
# |  *Order of Movies* | *Ordinal* | *Y-Ordering of rows* |
# |  *Label text * | *quatitative* | *Text Labels* |
# |  *Rating Category* | *ordinal* | *color* |
# |  *count of respondents* | *quantitative* | *x-position* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
#
# Which 'Star Wars' Movies Have You Seen?
#
# | Variable name| Variable Type (Ordinal/Nominal/Quantitative) | Variable encoding (color, x-position, etc.) |
# | --- | --- | --- |
# |  *movie title * | *Nominal* | *Y-Position* |
# |  *Viewing status* | *Nominal* | *color hue* |
# |  *status legent* | *Nominal* | *legent color* |
# |  *percentage not seen* | *quantitative* | *X-Position* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |
# |  *your answer* | *your answer* | *your answer* |

# %% [markdown]
# ### 1.2 A Pie Chart Version (15 points)
#
#
# !["Drawing"](/voc/data/have_seen_resized.png)
#
# Your colleague is arguing that the chart above could be made more *effective* by using one or more pie charts. In what situations are they right? In what situations would they be wrong? If it helps makes your case, feel free to create a picture (hand drawn is fine) and load it into the notebook.

# %% [markdown]
# When Pie Charts are Helpful:
#
# When showing proportions of a small number of categories (usually less than 5).
#
# When viewers need an immediate sense of how parts make up a whole.
#
# When the goal is to highlight one key segment relative to the rest.
#
# When the dataset is simple and the categories are clearly labeled.
#
# When comparisons are between large differences in sizes.
#
# When Pie Charts are Harmful:
#
# When there are many categories, making the slices too small and hard to distinguish.
#
# When precise comparison between categories is required (bar charts or dot plots are better).
#
# When parts do not sum up to a meaningful whole.
#
# When slight differences in values need to be perceived accurately.
#
# When categories have similarly sized portions, which makes it hard to tell them apart visually.

# %% [markdown]
# ## Part 2. Altair programming exercise (75 points)
# We have provided you with some code and parts of the article [America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/). This article is based on the dataset:
#
# 1. [StarWars](data/StarWars.csv) Created by FiveThirtyEight based on a survey ran through SurveyMonkey Audience, surveying 1,186 respondents from June 3 to 6 2014. Available [online] (https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
# To earn points for this assignment, you must:
#
# - Recreate the visualizations in the article (replace the images in the article with a code cell that creates a visualization). We provide one example. Each visualization is worth 10 points (40 points/ 10 each x 4 total ).
#
#     - _Partial credit can be granted for each visualization (up to 5 points) if you provide the grammar of graphics description of the visualization without a functional Altair implementation_
#
#
# - Propose two variants (a "good one" and a "bad one") for a new visualization for the article. You'll be asked to justify why one is better than the other. We are specifically interested in your explanation of why the "good one" is more *effective* based on principles of perception/cognition. (35 points/ 20 points for the plots + 15 for justification)

# %%
import pandas as pd
import altair as alt
import numpy as np
import math
from mads.lib.path import assets

# %%
# enable correct rendering
alt.renderers.enable('mimetype')
# Out:
# RendererRegistry.enable('mimetype')

# %%
# uses intermediate json files to speed things up
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
def loadStarwarsData(filename='StarWars.csv'):
    
    # input: filename to original dataset (default StarWars.csv)
    # output: cleaned up dataframe with columns appropriately renamed
    
    filename = assets.find(filename)
    sw = pd.read_csv(filename, encoding='latin1')

    # Some format is needed for the survey dataframe, we provide the formatted dataset in a dataframe 
    sw = sw.rename(columns={'Have you seen any of the 6 films in the Star Wars franchise?':'seen_any_movie',
                            'Do you consider yourself to be a fan of the Star Wars film franchise?': 'fan',
                            'Which of the following Star Wars films have you seen? Please select all that apply.' : 'seen_EI',
                            'Unnamed: 4' : 'seen_EII',
                            'Unnamed: 5' : 'seen_EIII',
                            'Unnamed: 6' : 'seen_EIV',
                            'Unnamed: 7' : 'seen_EV',
                            'Unnamed: 8' : 'seen_EVI',
                            'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.' : 'rank_EI',
                            'Unnamed: 10' : 'rank_EII',
                            'Unnamed: 11' : 'rank_EIII',
                            'Unnamed: 12' : 'rank_EIV',
                            'Unnamed: 13' : 'rank_EV',
                            'Unnamed: 14' : 'rank_EVI',
                            'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.' : 'Han Solo',
                            'Unnamed: 16' : 'Luke Skywalker',
                            'Unnamed: 17' : 'Princess Leia Organa',
                            'Unnamed: 18' : 'Anakin Skywalker',
                            'Unnamed: 19' : 'Obi Wan Kenobi',
                            'Unnamed: 20' : 'Emperor Palpatine',
                            'Unnamed: 21' : 'Darth Vader',
                            'Unnamed: 22' : 'Lando Calrissian',
                            'Unnamed: 23' : 'Boba Fett',
                            'Unnamed: 24' : 'C-3P0',
                            'Unnamed: 25' : 'R2 D2',
                            'Unnamed: 26' : 'Jar Jar Binks',
                            'Unnamed: 27' : 'Padme Amidala',
                            'Unnamed: 28' : 'Yoda',
                           })
    sw = sw.drop([0])
    return(sw)

sw = loadStarwarsData()

# %%
# take a peak to look at the data
sw.sample(5)
# Out:
#       RespondentID seen_any_movie  fan  \
# 909   3.289394e+09            Yes  Yes
# 405   3.290659e+09            Yes  Yes
# 1008  3.288666e+09             No  NaN
# 884   3.289467e+09            Yes  Yes
# 449   3.290553e+09            Yes   No
#
#                                        seen_EI  \
# 909                                        NaN
# 405                                        NaN
# 1008                                       NaN
# 884                                        NaN
# 449   Star Wars: Episode I  The Phantom Menace
#
#                                          seen_EII  \
# 909   Star Wars: Episode II  Attack of the Clones
# 405                                           NaN
# 1008                                          NaN
# 884                                           NaN
# 449   Star Wars: Episode II  Attack of the Clones
#
#                                         seen_EIII  \
# 909                                           NaN
# 405                                           NaN
# 1008                                          NaN
# 884   Star Wars: Episode III  Revenge of the Sith
# 449   Star Wars: Episode III  Revenge of the Sith
#
#                                seen_EIV  \
# 909                                 NaN
# 405   Star Wars: Episode IV  A New Hope
# 1008                                NaN
# 884                                 NaN
# 449   Star Wars: Episode IV  A New Hope
#
#                                            seen_EV  \
# 909                                            NaN
# 405   Star Wars: Episode V The Empire Strikes Back
# 1008                                           NaN
# 884   Star Wars: Episode V The Empire Strikes Back
# 449   Star Wars: Episode V The Empire Strikes Back
#
#                                       seen_EVI rank_EI  ...  \
# 909                                        NaN       4  ...
# 405   Star Wars: Episode VI Return of the Jedi       4  ...
# 1008                                       NaN     NaN  ...
# 884   Star Wars: Episode VI Return of the Jedi       4  ...
# 449   Star Wars: Episode VI Return of the Jedi       6  ...
#
#                                              Yoda  \
# 909   Neither favorably nor unfavorably (neutral)
# 405                                Very favorably
# 1008                                          NaN
# 884                                Very favorably
# 449                                Very favorably
#
#            Which character shot first?  \
# 909   I don't understand this question
# 405   I don't understand this question
# 1008                               NaN
# 884                             Greedo
# 449                                Han
#
#      Are you familiar with the Expanded Universe?  \
# 909                                           Yes
# 405                                            No
# 1008                                          NaN
# 884                                            No
# 449                                            No
#
#      Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 909                                                 Yes
# 405                                                 NaN
# 1008                                                NaN
# 884                                                 NaN
# 449                                                 NaN
#
#      Do you consider yourself to be a fan of the Star Trek franchise?  Gender  \
# 909                                                  No                Female
# 405                                                 Yes                  Male
# 1008                                                 No                  Male
# 884                                                 Yes                Female
# 449                                                 Yes                  Male
#
#         Age     Household Income           Education Location (Census Region)
# 909   18-29    $25,000 - $49,999     Bachelor degree       West North Central
# 405   30-44         $0 - $24,999     Graduate degree           South Atlantic
# 1008   > 60    $25,000 - $49,999  High school degree                  Pacific
# 884   45-60  $100,000 - $149,999     Bachelor degree                 Mountain
# 449   18-29    $50,000 - $99,999     Bachelor degree              New England
#
# [5 rows x 38 columns]

# %% [markdown]
# # America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)

# %% [markdown]
# _Original article available at [FiveThirtyEight](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/)_
#
# By [Walt Hickey](https://fivethirtyeight.com/contributors/walt-hickey/)
#
# Filed under [Movies](https://fivethirtyeight.com/tag/movies/)
#
# Get the data on [GitHub](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)

# %% [markdown]
# This week, I caught a sneak peek [of the X-Wing fighter](http://www.wired.com/2014/07/star-wars-episode-vii-x-wing/) from the new “Star Wars” films in production. The forthcoming movies — and the middling response to the most recent trilogy — provide a perfect excuse to examine some questions I’ve long wanted answers to: How many people are “Star Wars” fans? Does the rest of America realize that “The Empire Strikes Back” is clearly the best of the bunch? Which characters are most well-liked and most hated? And who shot first, Han Solo or Greedo?
#
# We ran a poll through [SurveyMonkey Audience](https://www.surveymonkey.com/mp/audience/), surveying 1,186 respondents from June 3 to 6 (the [data](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey) is available [on GitHub](https://github.com/fivethirtyeight/data)). Seventy-nine percent of those respondents said they had watched at least one of the “Star Wars” films. This question, incidentally, had a substantial difference by gender: 85 percent of men have seen at least one “Star Wars” film compared to 72 percent of women. Of people who have seen a film, men were also more likely to consider themselves a fan of the franchise: 72 percent of men compared to 60 percent of women.
#
# We then asked respondents which of the films they had seen. With 835 people responding, here’s the probability that someone has seen a given “Star Wars” film given that they have seen any Star Wars film:

# %% [markdown]
# !["Sol1"](/voc/data/have_seen_resized.png)

# %%
# We're going to fix the labels a bit so will create a mapping to the full names
# and have the full sort order
def genEpisodeNamesDF():
    # create the various mapping and order lists/dictionaries
    # return: list of episodes (in order), episode->name map, list of episode names (in order)
    episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
    names = {
        'EI' : 'The Phantom Menace', 'EII' : 'Attack of the Clones', 'EIII' : 'Revenge of the Sith', 
        'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'The Return of the Jedi'
    }

    # we're also going to use this order to sort, so names_l will now have our sort order
    return episodes, names, [names[ep] for ep in episodes]

episodes, namesDict, namesList = genEpisodeNamesDF()

# %%
# let's inspect what we've generated. These will be useful to you below
print("abbreviated list (sorted):\n  ",episodes)
print("\nmapping between abberviated names and full titles:\n  ",namesDict)
print("\nfull titles, sorted:\n  ",namesList)
# Out:
# abbreviated list (sorted):
#    ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
#
# mapping between abberviated names and full titles:
#    {'EI': 'The Phantom Menace', 'EII': 'Attack of the Clones', 'EIII': 'Revenge of the Sith', 'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI': 'The Return of the Jedi'}
#
# full titles, sorted:
#    ['The Phantom Menace', 'Attack of the Clones', 'Revenge of the Sith', 'A New Hope', 'The Empire Strikes Back', 'The Return of the Jedi']

# %%
# let's do some data pre-processing... recall that sw (star wars) has everything

def getSeenAtLeastOneDF(indf, eps):
    # input: indf the data file as formatted above
    # input: eps a list of episodes (movies)

    # returns a substet of the dataset
    
    # We want to only use those people who have seen at least one movie, let's get the people, toss NAs
    # and get the total count

    # find people who have at least on of the columns (seen_*) not NaN
    salo = indf.dropna(subset=['seen_' + ep for ep in eps],how='all')
    
    return(salo)

# %%
seenAtLeastOneDF = getSeenAtLeastOneDF(sw, episodes)
print("total who have seen at least one: ", len(seenAtLeastOneDF),"\nSample:")
display(seenAtLeastOneDF.sample(5))
# Out:
# total who have seen at least one:  835
# Sample:
#       RespondentID seen_any_movie  fan  \
# 383   3.290689e+09            Yes   No
# 100   3.291525e+09            Yes   No
# 984   3.288698e+09            Yes  Yes
# 1006  3.288668e+09            Yes  Yes
# 23    3.292512e+09            Yes  Yes
#
#                                        seen_EI  \
# 383   Star Wars: Episode I  The Phantom Menace
# 100   Star Wars: Episode I  The Phantom Menace
# 984   Star Wars: Episode I  The Phantom Menace
# 1006  Star Wars: Episode I  The Phantom Menace
# 23    Star Wars: Episode I  The Phantom Menace
#
#                                          seen_EII  \
# 383                                           NaN
# 100   Star Wars: Episode II  Attack of the Clones
# 984                                           NaN
# 1006  Star Wars: Episode II  Attack of the Clones
# 23    Star Wars: Episode II  Attack of the Clones
#
#                                         seen_EIII  \
# 383                                           NaN
# 100   Star Wars: Episode III  Revenge of the Sith
# 984                                           NaN
# 1006  Star Wars: Episode III  Revenge of the Sith
# 23    Star Wars: Episode III  Revenge of the Sith
#
#                                seen_EIV  \
# 383                                 NaN
# 100                                 NaN
# 984                                 NaN
# 1006  Star Wars: Episode IV  A New Hope
# 23    Star Wars: Episode IV  A New Hope
#
#                                            seen_EV  \
# 383                                            NaN
# 100                                            NaN
# 984                                            NaN
# 1006  Star Wars: Episode V The Empire Strikes Back
# 23    Star Wars: Episode V The Empire Strikes Back
#
#                                       seen_EVI rank_EI  ...  \
# 383                                        NaN       1  ...
# 100                                        NaN       1  ...
# 984                                        NaN       1  ...
# 1006  Star Wars: Episode VI Return of the Jedi       5  ...
# 23    Star Wars: Episode VI Return of the Jedi       6  ...
#
#                     Yoda Which character shot first?  \
# 383       Very favorably                      Greedo
# 100       Very favorably                      Greedo
# 984       Very favorably                         Han
# 1006  Somewhat favorably                      Greedo
# 23        Very favorably                      Greedo
#
#      Are you familiar with the Expanded Universe?  \
# 383                                            No
# 100                                            No
# 984                                            No
# 1006                                          Yes
# 23                                            Yes
#
#      Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 383                                                 NaN
# 100                                                 NaN
# 984                                                 NaN
# 1006                                                Yes
# 23                                                  Yes
#
#      Do you consider yourself to be a fan of the Star Trek franchise?  Gender  \
# 383                                                  No                  Male
# 100                                                  No                  Male
# 984                                                 Yes                Female
# 1006                                                Yes                  Male
# 23                                                  Yes                  Male
#
#         Age   Household Income                         Education  \
# 383   45-60  $50,000 - $99,999                High school degree
# 100    > 60  $50,000 - $99,999                   Bachelor degree
# 984    > 60  $25,000 - $49,999                   Graduate degree
# 1006  30-44  $50,000 - $99,999  Some college or Associate degree
# 23    18-29  $50,000 - $99,999                   Bachelor degree
#
#      Location (Census Region)
# 383        East North Central
# 100        East North Central
# 984                   Pacific
# 1006           South Atlantic
# 23             South Atlantic
#
# [5 rows x 38 columns]

# %%
# for each movie, we're going to calculate the percents and generate a new data frame

def genSeenPercentDf(inpf, names=namesDict, names_l=namesList):
    # input: inpf - an input frame of the form output by getSeenAtLeastOneDF()
    # input: names - a dictionary of abbreviations to names
    # input: names_l - a list of all the movies in series order
    
    total = len(inpf)
    percs = []

    # loop over each column and calculate the number of people who have seen the movie
    # specifically, filter out the people who are *NaN* for a specific episode (e.g., ep_EII), count them
    # and divide by the percent
    for seen_ep in ['seen_' + ep for ep in episodes]:
        perc = len(inpf[~ pd.isna(inpf[seen_ep])]) / total
        percs.append(perc)

    # at this point percs is holding our percentages

    # now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
    tuples = list(zip([names[ep] for ep in episodes],percs))
    seen_per_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])
    return(seen_per_df)

# %%
seenPerMovieDF = genSeenPercentDf(seenAtLeastOneDF)

# %%
# let's see what's inside
seenPerMovieDF
# Out:
#                       Name  Percentage
# 0       The Phantom Menace    0.805988
# 1     Attack of the Clones    0.683832
# 2      Revenge of the Sith    0.658683
# 3               A New Hope    0.726946
# 4  The Empire Strikes Back    0.907784
# 5   The Return of the Jedi    0.883832

# %%
def genPercentVis(indf, names_l=namesList):
    # input: indf, the dataframe as seen_per_df
    # input: names_l - a list of all the movies in series order (default namesList)
    # output: simple altair bar chart
    
    # ok, time to make the chart... let's make a bar chart (use mark_bar)
    bars = alt.Chart(indf).mark_bar(size=20).encode(
        # encode x as the percent, and hide the axis
        x=alt.X(
            'Percentage',
            axis=None),
        y=alt.Y(
            # encode y using the name, use the movie name to label the axis, sort using the names_l
            'Name:N',
             axis=alt.Axis(tickCount=5, title=''),
             # we give the sorting order to avoid alphabetical order
             sort=names_l
        )
    )

    # at this point we don't really have a great plot (it's missing the annotations, titles, etc.)
    return(bars)

seenPerMovieVis = genPercentVis(seenPerMovieDF)

# %%
# display it
seenPerMovieVis
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
def augmentPercentVis(base):
    # input: base (the base vis, i.e., bars as above)
    # we're going to overlay the text with the percentages, so let's make another visualization
    # that's just text labels


    text = base.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
    ).encode(
        # we'll use the percentage as the text
        text=alt.Text('Percentage:Q',format='.0%')
    )

    # finally, we're going to combine the bars and the text and do some styling
    seen_movies = (text + base).configure_mark(
        # we don't love the blue
        color='#008fd5'
    ).configure_view(
        # we don't want a stroke around the bars
        strokeWidth=0
    ).configure_scale(
        # add some padding
        bandPaddingInner=0.2
    ).properties(
        # set the dimensions of the visualization
        width=500,
        height=180
    ).properties(
        # add a title
        title="Which 'Star Wars' Movies Have you Seen?"
    )

    return(seen_movies)

# note that we are NOT formatting this in the Five Thirty Eight Style yet... we'll leave that to you to figure out

# %%
# let's see it
augmentPercentVis(seenPerMovieVis)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# So we can see that “Star Wars: Episode V — The Empire Strikes Back” is the film seen by the most number of people, followed by “Star Wars: Episode VI — Return of the Jedi.” Appallingly, more people reported seeing “Star Wars: Episode I — The Phantom Menace” than the original “Star Wars” (renamed “Star Wars: Episode IV — A New Hope”).
#
# So, which movie is the best? We asked the subset of 471 respondents who indicated they have seen every “Star Wars” film to rank them from best to worst. From that question, we calculated the share of respondents who rated each film as their favorite.

# %% [markdown]
# !["Sol1"](/voc/data/best_movie_article_resized.png)
#
#
# ** Homework note: Click [here](/voc/data/best_movie.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.1 What's the best 'Star Wars' movie? Recreate the above image using altair (10 Points)
#
# Recreate the image above using Altair. Match the "538" style as best you can (hint: look at the altair lab at the start of the semester). We expect you to *at least* match the [our version](best_movie.png) of the chart that was created in Altair.

# %%
# Recreate this image using Altair
# match the "538 style" as best you can (hint: look at the altair lab at the start of the semester)

#def genBestVis(inpf,eps, names=namesDict, names_l=namesList):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    # YOUR CODE HERE
 #   raise NotImplementedError()

import pandas as pd
import altair as alt

def genBestVis(inpf,eps, names=namesDict, names_l=namesList):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    # YOUR CODE HERE
    selected_columns = ['seen_EI', 'seen_EII', 'seen_EIII', 'seen_EIV', 'seen_EV', 'seen_EVI']

    sw_data = sw.dropna(subset=selected_columns)
    
    if names_l is None:
        names_l = list(names.values())
    
    percentages = []
    for ep in eps:
        column_name = f'rank_{ep}'
        percentages.append((sw_data[column_name] == '1').mean() * 100)

    data_df = pd.DataFrame({
        'Episode': [names[ep] for ep in eps],
        'Percentage': percentages,
        'Percentage_Text': [f"{p:.0f}%" for p in percentages]
    })
   
    bars = alt.Chart(data_df).mark_bar(color='#2F96DB', size=20).encode(
        y=alt.Y('Episode:O', sort=names_l, title="", axis=alt.Axis(labels=True, tickSize=12, domain=True, 
                labelFontSize=10, labelColor='grey', tickColor='grey', labelAlign='right')),
        x=alt.X('Percentage:Q', title="", 
                axis=alt.Axis(labels=False, ticks=False, domain=False, domainWidth=0, grid=False),
                scale=alt.Scale(range=[0,500]))
    )
    
    text = bars.mark_text(
        align='left',
        baseline='middle',
        dx=5,
        fontSize=11,
        font='Arial'
    ).encode(
        y=alt.Y('Episode:O', sort=names_l),
        x=alt.X('Percentage:Q', stack='zero'),
        text='Percentage_Text:N'
    )
    
 
    chart = alt.layer(bars, text).properties(
        width=400,
        height=150,
        padding={'top':3, 'left':1, 'bottom':7, 'right':5},
        title={
            "text": "What's the Best ‘Star Wars’ Movie?",
            "subtitle": f"Of {len(sw_data)} respondents who have seen all six films",
            "offset": 20,
            "dx": 5,
            "fontSize": 25,
            "fontWeight": 'bold',
            "subtitleFontSize": 12.5,
            "subtitleFontWeight": 'normal',
            "anchor": 'start',
            "subtitlePadding": 2
        },
        background='#F2F4F6'
    ).configure_view(strokeWidth=0 ).configure_axisLeft(labelPadding=10)   # Increase this value for more space
     
    return chart

# %%
# test your code
genBestVis(sw,episodes)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# ## Make sure to *style* your visualization to match the original the best you can

# %% [markdown]
# We can also drill down and find out, generally, how people rate the films. Overall, fans broke into two camps: those who preferred the original three movies and those who preferred the three prequels. People who said “The Empire Strikes Back” was their favorite were also likely to rate “A New Hope” and “Return of the Jedi” higher as well. Those who rated “The Phantom Menace” as the best film were more likely to rate prequels higher.
#
# This chart shows how often each film was rated in the top third (best or second-best), the middle third (third or fourth) or the bottom third (second-worst or worst). It’s a more nuanced take on the series:

# %% [markdown]
# !["Sol1"](/voc/data/how_rate_resized.png)
#
# ** Homework note: Click [here](/voc/data/people_rate.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.2 How people rate the 'Star Wars' movie? Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)

#def genRateVis(inpf,eps, names=namesDict, names_l=namesList):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
   # raise NotImplementedError()

## Recreate this image using altair here (10 POINTS)
import pandas as pd
import numpy as np
import io
import altair as alt
from altair import datum


def genRateVis(indf, eps, names, names_l):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    roman_to_int = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'VI': 6}  # Mapping Roman to Int

    selected_columns = [f'seen_{ep}' for ep in eps]
    sw_rate = indf[indf[selected_columns].notna().all(axis=1)].copy()
    
       
    categories=['Top third', 'Middle third', 'Bottom third']
    range_ = ['#4CAF50', '#2F96DB', '#F1482A']
    bins = [0, 2, 4, 6]
    new_data = []
    for ep in eps:
        col_name = f'rank_{ep}'
        sw_rate[col_name] = pd.to_numeric(indf[col_name], errors='coerce')
        sw_rate.dropna(subset=[col_name]) 
        sw_rate['Rating'] = pd.cut(sw_rate[col_name], bins, labels=categories)
        counts = sw_rate['Rating'].value_counts(normalize=True)# * 100
        for category in categories:
            
            new_data.append({
                'Episode': roman_to_int[ep[1:]],
                'Name': names[ep],
                'Rating': category,
                'Percentage': counts.get(category, 0)
            })
    
    sw_rate = pd.DataFrame(new_data)
    sw_rate.columns = ['Episode', 'Name', 'Rating', 'Percentage']
    
    
    bar1 = alt.Chart(sw_rate,title=categories[0]).mark_bar(size=20).encode(
        alt.Y('Name:O', sort=names_l, title='', axis=alt.Axis(labels=True, tickSize=11, domain=True, 
                labelFontSize=10, labelColor='grey', tickColor='grey', labelAlign='right', labelPadding=7)),
        alt.X('Percentage:Q', title=categories[0], axis=None, scale=alt.Scale(range=[0,70])),
        
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
        
    ).transform_filter(
        (datum.Rating == categories[0])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[0],
            fontSize=10,  
            font='Arial',
            offset=8) 
    
    )
    
    text1 = bar1.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )
    
    bar2 = alt.Chart(sw_rate,title=categories[1]).mark_bar(size=20).encode(
        alt.X('Percentage:Q', axis=None, scale=alt.Scale(range=[0,55])),
        alt.Y('Name:O', sort=names_l, axis=None),
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
    ).transform_filter(
        (datum.Rating == categories[1])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[1],
            fontSize=10,  
            font='Arial',
            offset=10,
            anchor='middle'
        )
    )

    text2 = bar2.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )

    bar3 = alt.Chart(sw_rate,title=categories[2]).mark_bar(size=20).encode(
        alt.X('Percentage:Q', axis=None, scale=alt.Scale(range=[0,75])),
        alt.Y('Name:O', sort=names_l, axis=None),
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
    ).transform_filter(
        (datum.Rating == categories[2])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[2],
            fontSize=10,  
            font='Arial',
            offset=8,
            anchor = 'middle'
        )
    )

    text3 = bar3.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )

    concat_chart = alt.hconcat(
        bar1+text1 ,bar2+text2, bar3+text3,
        ).configure(
        background='#F8F8F9'
    ).configure_view(
        stroke=None
    ).configure_axis(
        labelFontSize = 10,
        domainOpacity = 0.4,
        labelColor = 'grey',
        labelOpacity = 1,
        labelFont = 'Arial',
        labelFontWeight = 300,
        labelPadding = 3,
        tickSize = 10,
        tickColor = '#ababab',
        tickOpacity = 1
    ).configure_title(
        
        fontSize = 25,
        fontWeight = 'bold',
        dy = -5,
        subtitleColor = '#000000',
        subtitleFontWeight = 'normal',
        subtitlePadding = 3,
        offset = 15,
        dx = 1
    ).properties(
        title={'text': "How People Rate the 'Star Wars' Movies",
               'subtitle': ["How often each film was rated in the top, middle and bottom third",
               "(by 471 respondents who have seen all six films)"]
          },
        spacing = 45,
        padding={'top':3, 'left':10, 'bottom':7, 'right':5}
    )
    
    
    
    
    return concat_chart

episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']

namesDict = {
    'EI' : 'The Phantom Menace', 'EII' : 'Attack of the Clones', 'EIII' : 'Revenge of the Sith', 
    'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'Return of the Jedi'
}

namesList = list(namesDict.values())

# %%
# let's check our solution
#genRateVis(sw,episodes)
genRateVis(sw, episodes, namesDict, namesList)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# Finally, we took a boilerplate format used by political favorability polls — “Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her” — and asked respondents to rate characters in the series.

# %% [markdown]
# !["Sol1"](/voc/data/char_ranking_resized.png)
#
#
# ** Homework note. Here's an example solution generated in Altair:
# !["Sol1"](/voc/data/people_rate_s.png)
#
# Be careful here in what you're dividing by to get the totals for each character.

# %% [markdown]
# ### 2.3 Star Wars' Characters Favorability Ratings. Recreate the above image using altair (10 Points)

# %%
## Recreate this image using altair here (10 POINTS)
import pandas as pd
import numpy as np
import io
import altair as alt
from altair import datum


def genRateVis(indf, eps, names, names_l):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    roman_to_int = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'VI': 6}  # Mapping Roman to Int

    selected_columns = [f'seen_{ep}' for ep in eps]
    sw_rate = indf[indf[selected_columns].notna().all(axis=1)].copy()
    
       
    categories=['Top third', 'Middle third', 'Bottom third']
    range_ = ['#4CAF50', '#2F96DB', '#F1482A']
    bins = [0, 2, 4, 6]
    new_data = []
    for ep in eps:
        col_name = f'rank_{ep}'
        sw_rate[col_name] = pd.to_numeric(indf[col_name], errors='coerce')
        sw_rate.dropna(subset=[col_name]) 
        sw_rate['Rating'] = pd.cut(sw_rate[col_name], bins, labels=categories)
        counts = sw_rate['Rating'].value_counts(normalize=True)# * 100
        for category in categories:
            
            new_data.append({
                'Episode': roman_to_int[ep[1:]],
                'Name': names[ep],
                'Rating': category,
                'Percentage': counts.get(category, 0)
            })
    
    sw_rate = pd.DataFrame(new_data)
    sw_rate.columns = ['Episode', 'Name', 'Rating', 'Percentage']
    
    
    bar1 = alt.Chart(sw_rate,title=categories[0]).mark_bar(size=20).encode(
        alt.Y('Name:O', sort=names_l, title='', axis=alt.Axis(labels=True, tickSize=11, domain=True, 
                labelFontSize=10, labelColor='grey', tickColor='grey', labelAlign='right', labelPadding=7)),
        alt.X('Percentage:Q', title=categories[0], axis=None, scale=alt.Scale(range=[0,70])),
        
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
        
    ).transform_filter(
        (datum.Rating == categories[0])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[0],
            fontSize=10,  
            font='Arial',
            offset=8) 
    
    )
    
    text1 = bar1.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )
    
    bar2 = alt.Chart(sw_rate,title=categories[1]).mark_bar(size=20).encode(
        alt.X('Percentage:Q', axis=None, scale=alt.Scale(range=[0,55])),
        alt.Y('Name:O', sort=names_l, axis=None),
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
    ).transform_filter(
        (datum.Rating == categories[1])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[1],
            fontSize=10,  
            font='Arial',
            offset=10,
            anchor='middle'
        )
    )

    text2 = bar2.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )

    bar3 = alt.Chart(sw_rate,title=categories[2]).mark_bar(size=20).encode(
        alt.X('Percentage:Q', axis=None, scale=alt.Scale(range=[0,75])),
        alt.Y('Name:O', sort=names_l, axis=None),
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
    ).transform_filter(
        (datum.Rating == categories[2])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[2],
            fontSize=10,  
            font='Arial',
            offset=8,
            anchor = 'middle'
        )
    )

    text3 = bar3.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )

    concat_chart = alt.hconcat(
        bar1+text1 ,bar2+text2, bar3+text3,
        ).configure(
        background='#F8F8F9'
    ).configure_view(
        stroke=None
    ).configure_axis(
        labelFontSize = 10,
        domainOpacity = 0.4,
        labelColor = 'grey',
        labelOpacity = 1,
        labelFont = 'Arial',
        labelFontWeight = 300,
        labelPadding = 3,
        tickSize = 10,
        tickColor = '#ababab',
        tickOpacity = 1
    ).configure_title(
        
        fontSize = 25,
        fontWeight = 'bold',
        dy = -5,
        subtitleColor = '#000000',
        subtitleFontWeight = 'normal',
        subtitlePadding = 3,
        offset = 15,
        dx = 1
    ).properties(
        title={'text': "How People Rate the 'Star Wars' Movies",
               'subtitle': ["How often each film was rated in the top, middle and bottom third",
               "(by 471 respondents who have seen all six films)"]
          },
        spacing = 45,
        padding={'top':3, 'left':10, 'bottom':7, 'right':5}
    )
    
    
    
    
    return concat_chart

episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']

namesDict = {
    'EI' : 'The Phantom Menace', 'EII' : 'Attack of the Clones', 'EIII' : 'Revenge of the Sith', 
    'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'Return of the Jedi'
}

namesList = list(namesDict.values())

# %%
# let's test the solution
genFavorabilityVis(sw)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # let's test the solution
# ----> 2 genFavorabilityVis(sw)
#
# Cell In[28], line 97, in genFavorabilityVis(inpf)
#      94         cur_len = 0
#      96 if best_len == 0:
# ---> 97     raise ValueError("Could not locate the character favorability columns.")
#      99 start_idx = best_start
#     100 stop_idx = best_start + best_len
#
# ValueError: Could not locate the character favorability columns.

# %% [markdown]
# !["Sol1"](/voc/data/shot_first_article_resized.png)
#
#
# ** Homework note: Click [here](/voc/data/shot_first.png) to see a version of this plot generated in Altair. You may find that you don't get 834 rows (as 538 did) but the percents should still work.

# %% [markdown]
# ### 2.4 Who shot first? Recreate the above image using altair (10 Points)

# %%
# Recreate this image using altair here (10 POINTS)

# Recreate this image using altair here (10 POINTS)

def genFirstShotVis(inpf):
    # input: inpf, the star wars dataset
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
    counts = sw["Which character shot first?"].value_counts()
    
    total = np.sum(counts.values)
    
    
    # Calculate percentages
    percentages = {key: round((value / total) * 100) for key, value in counts.items()}

    # Create a DataFrame using the calculated percentages
    df = pd.DataFrame({
        'Question': list(percentages.keys()),
        'Percentage': list(percentages.values())
    })
    
    namesList = ["Han", "Greedo", "I don't understand this question"]
    names_l = namesList
    bars = alt.Chart(df).mark_bar(color='#2F96DB', size=20).encode(
        y=alt.Y('Question:O', sort=names_l, title="", axis=alt.Axis(labels=True, 
                labelColor='#898A8B', tickSize=12, domain=True, domainColor='#898A8B', tickColor='#898A8B',
                labelFontSize=10, labelPadding=11)),
        x=alt.X('Percentage:Q', title="", 
                axis=alt.Axis(labels=False, ticks=False, domain=False, domainWidth=0, grid=False),
                scale=alt.Scale(range=[0,500]))
    )
    
    text = bars.mark_text(
        align='left',
        baseline='middle',
        dx=5,
        fontSize=11.5,
        font='Courier'
    ).transform_calculate(
        percentage_text="datum.Percentage + '%'"
    
    ).encode(
        y=alt.Y('Question:O', sort=names_l),
        x=alt.X('Percentage:Q', stack='zero'),
        text=alt.Text('percentage_text:N')
    )
    
    
 
    chart = alt.layer(bars, text).properties(
        width=400,
        height=100,
        padding={'top':3, 'left':1, 'bottom':7, 'right':5},
        title={
            "text": "Who shot first?",
            "subtitle": "According to 828 respondents",
            "offset": 20,
            "dx": 5,
            "fontSize": 25,
            "fontWeight": 'bold',
            "subtitleFontSize": 12.5,
            "subtitleFontWeight": 'normal',
            "anchor": 'start',
            "subtitlePadding": 3
        },
        background='#F2F4F6'
    ).configure_view(strokeWidth=0 ).configure_axisLeft(labelPadding=0)   # Increase this value for more space
    
    return chart

# %%
# test our solution
genFirstShotVis(sw)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# ### 2.5 Make your own (35 points total - 20 for implementation, 15 for justification)

# %% [markdown]
# Reading through the article, identify some aspect of the story that would benefit from an extra visualization (you can imagine extending the article if it helps). We would like for you to create two versions of this hypothetical visualization.  You should be able to convincingly argue that one visualization is better than the other.
#
# Note: The two visualizations should use different marks and at least some of the encodings should be different. If you're struggling with coming up with two really different representations, your visualization may simply be too simple. Try to add additional columns/comparisons.

# %%
# YOUR CODE HERE
# add your code for the "worse version" here
# add your code for the "better version" here

## Recreate this image using altair here (10 POINTS)
import pandas as pd
import numpy as np
import io
import altair as alt
from altair import datum   


def betterVis(indf, eps, names, names_l):
    
    roman_to_int = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'VI': 6}  # Mapping Roman to Int
    
    sw_cleaned = indf.drop(['Luke Skywalker', 'Han Solo', 'Princess Leia Organa', 'Anakin Skywalker',
                              'Obi Wan Kenobi','Emperor Palpatine', 'Darth Vader','Lando Calrissian', 
                              'Boba Fett', 'C-3P0', 'R2 D2', 'Padme Amidala','Yoda'], axis=1) 
    
    sw_cleaned = sw_cleaned.dropna(how='all')
    
    selected_columns = [f'seen_{ep}' for ep in eps]
    
    sw_jar = sw_cleaned[sw_cleaned[selected_columns].notna().all(axis=1)].copy()
    
    sw_jar['Jar Jar Binks'] = sw_jar['Jar Jar Binks'].replace(responseDict)
   
    sw_jar = sw_jar.loc[sw_jar['Jar Jar Binks'].isin([4,5])]
    
    
    categories=['Top third', 'Middle third', 'Bottom third']
    range_ = ['#4CAF50', '#2F96DB', '#F1482A']
    bins = [0, 2, 4, 6]
    new_data = []
    for ep in eps:
        col_name = f'rank_{ep}'
        sw_jar[col_name] = pd.to_numeric(indf[col_name], errors='coerce')
        sw_jar.dropna(subset=[col_name]) 
        sw_jar['Rating'] = pd.cut(sw_jar[col_name], bins, labels=categories)
        counts = sw_jar['Rating'].value_counts(normalize=True)# * 100
                
        for category in categories:
            
            new_data.append({
                'Episode': roman_to_int[ep[1:]],
                'Name': names[ep],
                'Rating': category,
                'Percentage': counts.get(category, 0)
            })
    
    sw_jar = pd.DataFrame(new_data)
    sw_jar.columns = ['Episode', 'Name', 'Rating', 'Percentage']
        
    bar1 = alt.Chart(sw_jar,title=categories[0]).mark_bar(size=20).encode(
        alt.Y('Name:O', sort=names_l, title='', axis=alt.Axis(labels=True, tickSize=11, domain=True, 
                labelFontSize=10, labelColor='grey', tickColor='grey', labelAlign='right', labelPadding=7)),
        alt.X('Percentage:Q', title=categories[0], axis=None),
        
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
        
    ).transform_filter(
        (datum.Rating == categories[0])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[0],
            fontSize=10,  
            font='Arial',
            offset=15) 
    
    )
    
    text1 = bar1.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )
    
    bar2 = alt.Chart(sw_jar,title=categories[1]).mark_bar(size=20).encode(
        alt.X('Percentage:Q', axis=None),
        alt.Y('Name:O', sort=names_l, axis=None),
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
    ).transform_filter(
        (datum.Rating == categories[1])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[1],
            fontSize=10,  
            font='Arial',
            offset=15 
        )
    )

    text2 = bar2.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )

    bar3 = alt.Chart(sw_jar,title=categories[2]).mark_bar(size=20).encode(
        alt.X('Percentage:Q', axis=None),
        alt.Y('Name:O', sort=names_l, axis=None),
        color=alt.Color('Rating:N', legend=None, scale=alt.Scale(domain=categories, range=range_)),
    ).transform_filter(
        (datum.Rating == categories[2])
    ).properties(
        width=75,
        height=150,
        title=alt.TitleParams(
            text=categories[2],
            fontSize=10,  
            font='Arial',
            offset=15 
        )
    )

    text3 = bar3.mark_text(
        align='left',
        baseline='middle',
        dx=3
    ).encode(
        text=alt.Text('Percentage:Q', format='.0%')
    )

    
    
    
      
   
    concat_chart = alt.hconcat(
        bar1+text1 ,bar2+text2, bar3+text3,
        ).configure(
        background='#F8F8F9'
    ).configure_view(
        stroke=None
    ).configure_axis(
        labelFontSize = 10,
        domainOpacity = 0.4,
        labelColor = 'grey',
        labelOpacity = 1,
        labelFont = 'Arial',
        labelFontWeight = 300,
        labelPadding = 3,
        tickSize = 10,
        tickColor = '#ababab',
        tickOpacity = 1
    ).configure_title(
        
        fontSize = 25,
        fontWeight = 'bold',
        dy = -5,
        subtitleColor = '#000000',
        subtitleFontWeight = 'normal',
        subtitlePadding = 3,
        offset = 15,
        dx = 1
    ).properties(
        title={'text': "How Jar Jar Non-Fans Rate 'Star Wars' Movies",
               'subtitle': ["Of respondents who have seen all six films and viewed Jar Jar 'Somewhat UnFavorably' or 'Very Favorably'"]
          },
        spacing = 45,
        padding={'top':3, 'left':10, 'bottom':7, 'right':0}
    )
        
    
    return concat_chart
responseDict = {
    'Very favorably' : 1, 'Somewhat favorably' : 2, 'Neither favorably nor unfavorably (neutral)' : 3, 
    'Somewhat unfavorably': 4, 'Very unfavorably': 5, 'Unfamiliar (N/A)' : 6, 
    }
charList = ['Jar Jar Binks']


episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']

namesDict = {
    'EI' : 'The Phantom Menace', 'EII' : 'Attack of the Clones', 'EIII' : 'Revenge of the Sith', 
    'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'Return of the Jedi'
}

namesList = list(namesDict.values())

chart = betterVis(sw, episodes, namesDict, namesList)
chart
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
# YOUR CODE HERE
# add your code for the "better version" here
def worseVis(sw,eps, names=namesDict, names_l=None):
    # input: inpf, the star wars dataset
    # input: eps, the list of episodes
    # input: names - a dictionary of abbreviations to names (default: namesDict)
    # input: names_l - a list of all the movies in series order (default: namesList)
    # output: the Altair visualization as described above
    
    # YOUR CODE HERE
    roman_to_int = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, 'VI': 6}
    
    
    
    
    sw_cleaned = sw.drop(['Luke Skywalker', 'Han Solo', 'Princess Leia Organa', 'Anakin Skywalker',
                              'Obi Wan Kenobi','Emperor Palpatine', 'Darth Vader','Lando Calrissian', 
                              'Boba Fett', 'C-3P0', 'R2 D2', 'Padme Amidala','Yoda'], axis=1) 
    
    sw_cleaned = sw_cleaned.dropna(how='all')
    
    selected_columns = [f'seen_{ep}' for ep in eps]
    
    
    sw_cleaned = sw_cleaned[sw_cleaned[selected_columns].notna().all(axis=1)].copy()
    
    sw_cleaned['Jar Jar Binks'] = sw_cleaned['Jar Jar Binks'].replace(responseDict)
    
    sw_jar = sw_cleaned.loc[sw_cleaned['Jar Jar Binks'].isin([4,5])] 
    print(len(sw_jar))
    
    
    if names_l is None:
        names_l = list(names.values())
    
    percentages = []
    for ep in eps:
        column_name = f'rank_{ep}'
        percentages.append((sw_jar[column_name] == '1').mean() * 100)

    sw_jar = pd.DataFrame({
        'Episode': [names[ep] for ep in eps],
        'Percentage': percentages,
        'Percentage_Text': [f"{p:.0f}%" for p in percentages]
    })

    

    
    bars = alt.Chart(sw_jar).mark_circle(color='#2F96DB', size=75).encode(
        y=alt.Y('Percentage:Q', title="Percentage", axis=alt.Axis(labels=True, tickSize=12, domain=True, 
                labelFontSize=10, labelColor='grey', tickColor='grey', labelAlign='right')),
        x=alt.X('Episode:O', sort=names_l, title="Episodes", axis=alt.Axis(labels=True, ticks=True, 
                domain=True, domainWidth=1, grid=True, labelAngle=-45),
                scale=alt.Scale(range=[0,500]))
    )
    
    text = bars.mark_text(
        align='left',
        baseline='middle',
        dx=5,
        fontSize=11,
        font='Arial'
    ).encode(
        y=alt.Y('Percentage:Q'),
        x=alt.X('Episode:O', sort=names_l, stack='zero'),
        text='Percentage_Text:N'
    )
    
    
 
    chart = alt.layer(bars, text).properties(
        width=400,
        height=150,
        padding={'top':3, 'left':1, 'bottom':7, 'right':5},
        title={
            "text": "How Jar Jar Non-Fans Rate 'Star Wars' Movies",
            "subtitle": ["Of respondents who have seen all six films and viewed Jar Jar 'UnFavorably' or 'Very Favorably'"],
            "offset": 20,
            "dx": 5,
            "fontSize": 25,
            "fontWeight": 'bold',
            "subtitleFontSize": 12.5,
            "subtitleFontWeight": 'normal',
            "anchor": 'start',
            "subtitlePadding": 2
        },
        background='#F2F4F6'
    ).configure_view(strokeWidth=0 ).configure_axisLeft(labelPadding=10)   # Increase this value for more space
     
    return chart  #print(sw['rank_EII'].unique())            # print((sw_data['rank_EIII'] == 1).sample(10))


worseVis(sw,episodes, namesDict, namesList)
# Out:
# 223
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# #### Justification
# *Provide your justification here* to argue why your "better" version is actually better. Make sure to defend this based on expressiveness and effectiveness as well as perceptual arguments.

# %% [markdown]
# I looked into why so many Star Wars fans dislike Jar Jar Binks. As someone who feels the same way, I wanted to see how this dislike affects how people rate the different movies—especially among those who don’t like Jar Jar. The data showed a clear divide between fans: people who love the original trilogy versus those who prefer the prequels. Fans of The Empire Strikes Back rated the original trilogy higher, while The Phantom Menace fans rated the prequels higher. I wanted to see how Jar Jar’s unpopularity fit into these ratings.
#
# The first visualization I made didn’t show this very well. It only displayed the top-rated movie among people who disliked Jar Jar, which left out a lot of useful information. It didn’t show how all the movies ranked overall, making it hard to understand the full picture.
#
# My improved visualization fixes this by grouping all the movies by rank. This gives a clearer and more balanced look at how Jar Jar’s unpopularity influenced movie ratings. In the first version, it looked like people’s dislike for Jar Jar completely erased appreciation for the original trilogy. The new version, however, shows that the original movies still hold a solid place, often appearing in the middle rankings.
#
# The new chart avoids exaggerating the extremes, but it still shows that Jar Jar’s presence was linked to lower ratings. As his role shrinks from Episode I to III, the number of “Top third” ratings rises, while the “Bottom third” ratings fall—especially by Episode III, which shows a big 25-point drop.
#
# This new visualization makes it easier to see Jar Jar’s effect on fans’ ratings without overstating it. It provides a fairer and more detailed picture of how people view the movies.
#
# When we talk about effectiveness and expressiveness in visualizations:
#
# Effectiveness means how clearly and accurately the chart communicates its message. An effective visualization helps people quickly understand the data and draw correct conclusions.
#
# Expressiveness means how completely the visualization represents the data. An expressive visualization includes all relevant information without leaving important parts out.
#
# Comparing the two:
#
# The first visualization was less expressive because it only showed the single highest-rated movie. That made it incomplete.
#
# The improved one is more expressive since it shows how all movies are ranked, giving a full picture.
#
# The first was also less effective, because it might make people think Jar Jar had a bigger negative impact than he really did.
#
# The improved one is more effective, because it presents a balanced, realistic view—showing that while Jar Jar’s presence mattered, it didn’t completely overshadow everything else.
#
# In short, the new visualization is both more expressive and effective. It gives a fuller, more accurate, and more balanced understanding of how Jar Jar Binks’ unpopularity influenced Star Wars movie ratings.
